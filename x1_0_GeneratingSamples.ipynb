# %% [markdown]
# # Generating Samples

# %% [markdown]
# In this notebook we will show how to generate valid samples for a given parser without using a grammar.

# %% [markdown]
# ## Examples

# %% [markdown]
# Convenience utilities

# %%
import src.utils as utils

# %% [markdown]
# ### Calculator.py

# %%
calculator = utils.load_file('subjects/calculator.py', 'calculator')

# %% [markdown]
# #### The error handler

# %% [markdown]
# We often need to interpret the error we get back. We use a simple exception class to capture the error.

# %%
with utils.ExpectError():
     calculator.main('xyz')
# Out:
# ('xyz', 0)

# %% [markdown]
# #### A random fuzzer.

# %%
import random
random.seed(0)

# %%
import string

# %%
def fuzzer(max_length=100):
    string_length = random.randrange(1, max_length + 1)
    return ''.join([random.choice(string.printable) for c in range(string_length)])

# %%
fuzzer()
# Out:
# "\rR5x$!PCZJ-r#hAh\nc<w'{:iDc~9^GY*cJTE;>q)ZU%x7)1b}P"

# %% [markdown]
# What happens if you feed this input to the program?

# %%
with utils.ExpectError():
    s = fuzzer()
    print(repr(s))
    calculator.main(s)
# Out:
# '\\=0;"Gv~F{8o+sui(VbaE$!dC)B{f)G(q:).AUb/NE,uBnon4;[xY8b]\ngj4a`(^O{&z%ur].R-zV"[?`JaF;e!.=Go'
# ('\\=0;"Gv~F{8o+sui(VbaE$!dC)B{f)G(q:).AUb/NE,uBnon4;[xY8b]\ngj4a`(^O{&z%ur].R-zV"[?`JaF;e!.=Go', 0)

# %% [markdown]
# This is rather unsatisfying. We need a better way to reach deeper into the program. Let us observe the error again, this time with a plausible partial input.

# %%
with utils.ExpectError():
     calculator.main('(1+2)de')
# Out:
# ('(1+2)de', 5)

# %% [markdown]
# As you can see, the exception we got precisely indicates exactly where the parse error occurred.

# %%
'(1+2)de'[0:5]
# Out:
# '(1+2)'

# %% [markdown]
# Can we make use of it to construct better inputs?

# %%
import enum

# %%
class ExprStatus(enum.Enum):
    Complete = 0
    Unterminated = -1
    Unexpected = -2

# %%
class ExpectExprError:
    def __init__(self, s, log=True):
        self.msg = None
        self.boundary = None
        self.result = None
        self.s = s
        self.log = log

    def __enter__(self):
        return self

    def __exit__(self, exc_type, exc_value, tb):
        if exc_type is None:
            self.boundary = 0
            self.result = ExprStatus.Complete
            return
        inp, self.boundary = exc_value.args
        if self.boundary >= len(self.s):
            self.result = ExprStatus.Unterminated
        elif self.boundary < len(self.s):
            self.result =  ExprStatus.Unexpected
        else:
            assert False
        return True

# %%
with ExpectExprError('(1+2x)') as e:
     calculator.main(e.s)
e.boundary, e.result
# Out:
# (4, <ExprStatus.Unexpected: -2>)

# %%
with ExpectExprError('(1+2') as e:
     calculator.main(e.s)
e.boundary, e.result
# Out:
# (4, <ExprStatus.Unterminated: -1>)

# %%
with ExpectExprError('(1+2)') as e:
     calculator.main(e.s)
e.boundary, e.result
# Out:
# (0, <ExprStatus.Complete: 0>)

# %%
with ExpectExprError('(1+2)x') as e:
     calculator.main(e.s)
e.boundary, e.result
# Out:
# (5, <ExprStatus.Unexpected: -2>)

# %% [markdown]
# The chicken and egg problem; we need to use dynamic analysis; which means we need to have a few valid inputs.

# %% [markdown]
# #### Building the Evolutionary Algorithm

# %%
def get_expr_fitness(s):
    with ExpectExprError(s) as e:
        calculator.main(e.s)
    match e.result:
        case ExprStatus.Complete:
            return 1.0/len(e.s)
        case ExprStatus.Unexpected:
            return len(e.s) - e.boundary
        case ExprStatus.Unterminated:
            return 1
    assert False, (s, e)

# %%
class Evolver:
    def __init__(self, fitness_fn=None, delta=0.1, log=True):
        self.fitness_fn = fitness_fn
        self.log = log
        self.delta = delta
        
    def get_fitness(self, s):
        return self.fitness_fn(s)

# %%
expr_evolver = Evolver(get_expr_fitness)

# %%
expr_evolver.get_fitness('(1+2)')
# Out:
# 0.2

# %%
expr_evolver.get_fitness('(1+(2*4+4))')
# Out:
# 0.09090909090909091

# %%
expr_evolver.get_fitness('(1+2)234')
# Out:
# 3

# %%
expr_evolver.get_fitness('(1+2+3')
# Out:
# 1

# %%
expr_evolver.get_fitness('(1+2+3XXY')
# Out:
# 3

# %%
class Evolver(Evolver):
    def create_population(self, size):
        return [fuzzer() for i in range(size)]

# %%
expr_evolver = Evolver(get_expr_fitness)

# %%
expr_evolver.create_population(10)
# Out:
# ["2~ye{sLlGS7ci`s5,>':^93f>o:,fObL",
#  '4:2on|fZq~7]2(S',
#  'cx8s9?CITn7#X5/c`OpxJ~Y+l`]q\x0b7]kkH&wf/U\\m1Y^Q+$D@JN[wj*_1W aG 5(zhu\rZJ;A]J.><g|D',
#  '\tR@a0/o`Gkus>VM{]+R4P`+R\x0b[{5lV8x`kV&!*:\n04"FDX6Ro)',
#  'a}g1P]RE0r1|\n0]&;cof:@pCz_ncYO=a2zVewh@%@?Iejz255q^x*EK+5\t`:@"|?W>TL\'mqM.B1hjyGHL|',
#  'H\x0c<45ykj-BKO',
#  'gBeZ~u6Dm%~9CPGCRdc*ZYHHfZe`"S4CG ^jl=+M>b8ap\ts7N1cO*%BV!-|]rSaLsx-\x0clTo',
#  'e8`3&V\n]pf"Owq?5r<idpWMK(jd/!i+P>^S%"]F"">\\p(;',
#  '1H{\tEF4&iw:jM-B|{Y8a%58sg5C1\r',
#  'Gkj@WL#M&#4,b]%\r/9\tS\nqB\'/RZN:.t2[0 nC#+wG8"xC\x0bQNN7k?guA~G7']

# %%
class Evolver(Evolver):
    def evaluate_population(self, population):
        fitness = [self.get_fitness(x) for x in population]
        return list(zip(population, fitness))

# %%
expr_evolver = Evolver(get_expr_fitness)

# %%
population = expr_evolver.create_population(100)
expr_evolver.evaluate_population(population)
# Out:
# [('ZRi!:', 5),
#  ('a]`jJQ4;XNW6cY\x0cj24/<g=Fd`)@IoN\x0c\x0c!e7;`X;=H@f^|<BgNB\t^f%o4OUL\noWJ=955!w3%\\+,rtb\x0c=\x0c#`&R#DeiS+Sa',
#   92),
#  ('R8cR\x0cj~3VT^R3"', 14),
#  ('}waJ9fJ_3IIm1tK9/iq0q[]~f\t0BL_3:tinWeZI{xg', 42),
#  ('qKGY', 4),
#  ("B)>Fn.ad'-DkMigsE$vu\nnBLR[5g/2O9`9gRC)", 38),
#  (' i.SC>JavU=L>&7MQ1R~FUqLBYbndze*:_j`VPn\x0bRTmvWH%iJX=>bZ', 54),
#  ('qB0`V<X0rCe\x0b=C(:jS{\nYb]"\rt(\rPz=2fy\\50wO&-{OUd\twJA\n]p/a49xD\'Hf&v\rk8RBA%h,%=q\'dQ>(P \x0czBUL+=hkf`fMP.',
#   97),
#  ('h*\\CJ=Y\tRrZ!_#E"@7UCi\t"6<r3JYO1&8^a^ \\O0K5e<0y>`B~ti\n,AodTW|', 60),
#  ('NlGR?^TiV{i&EgqnUINS!N~spUq.{6N4t>anK7\t>]mt', 43),
#  ("C;b{$\nA\x0bJQW6=`%\\@) T-W!w{YrHy556kI0B@0h8S^s:O*sWoH:d:aEF'WFw3%5oLaq&Iopw]~ CD%N",
#   79),
#  ('ZI|u5D)91W"}U6Q"WUfaauc\rjQrU;9S*\n', 33),
#  ("5nv!sgzJETd*A;(p|B\x0cU$:X'>xyt2f;|cm~RvrA [0 '$S6fN?y", 50),
#  (' +Jt]|{([As u8%D', 16),
#  ('FtL=ZA-lh1)#FK->3gOjm$9h\rq\x0c"+\x0b`ru~gt\rNJ:.g="d;3&/J!WD1s*@k[" Z(E{axh:P{oEBN7q4E}\tvHU\\}[',
#   87),
#  ("sxI\\kD2J,(7~=jJ2!=73u51s@F87I[ShrVTiJDm@G~\tQM1Qx'' ^{X\r5+fQNl0#h<[$~`iaGumv2l\t^*l|aS/",
#   85),
#  ('<=W{j;:5wH ~M3', 14),
#  ('4"bJB\\jWu#Jk \nPHy"O1D&A)Y4\x0b\',)x^4WO}fPI"62y 4w^^-`\x0cB^\rq\r&%HNwqe+Gv.]}\'^JkjG\t1-6+j',
#   80),
#  ('KB=BF"P/Tl0i+5UgH1}Z\\[\x0cw\t;o8)Szm&l8[>k-e#=(:N', 45),
#  ('TyDA1S\x0c|zx\'&)EHo{Ti0\n$j[`+NKX4*Q>;\rt2K&k^o=J=`"2~ v,uzn\rR9,Vu\t|V${colU8S>OywT\n\x0cJ;FbD3"1\rwp\rONT\x0c>=',
#   97),
#  ('N`4-XJ+g+{zF3OY%h5a+IK08o|e\\(Y5E3EOg\r>zQ\\i/iPD$7kghZ{?|\r}5~%5*_\t`=NnI-aa*mxpxF`{wx%Wj\nV',
#   87),
#  ('j4=-m?$4\nE9o?W;uW%k{G@hY\x0b*7(a%H0\x0cadS:J+VGM$K>fhE2n~g2H:o5Q?7`DN6/\x0b|lJ9Q',
#   71),
#  ('UJ:<\nw]', 7),
#  ('+WQn3WxoN8Jcf3I2mP;_@1FW)\t_"Ya6\'Px3?%caG', 40),
#  ('cY4j%=A40MHk)`ikm\x0ck>^v<G3Z=]O5su>AGluJskRXK+hN', 46),
#  ("\x0b1k-0^N|mj23F$046\x0ce,;i\x0cj]M3RT+^G|vhK$r'P9gQ+[IcTTvYMsOu?ZO-8wz&L(2:;\x0cYuz5",
#   73),
#  ("FO=d'6i|O3\x0bR~OTd|W:XklHYQk.A\r#eLIi=J\x0bY=%\n6pwm}-FBM>5B)T4^QyM~qIhge;Jl3T,OX9?{{^",
#   79),
#  ('\x0cS(})hljql', 10),
#  ('3&h"J< A|G^fQ\x0bxkH=#G\'_iM \t*DuM', 29),
#  ('NY$DQQc^ji0-/>{%d`\x0c?`q/?:$ey_~;lMa41eK}ZEd]VL', 45),
#  ('`w\\!\x0ctk*)9\x0c$l3?l%Q:[qU{^Px2.hNlU+6Mb?.PGt#W5Z<dy#!)?OYxnt(KkC:iW88ZO+Q*bxZt',
#   75),
#  ('BiKch[7\\h.*p04P', 15),
#  ('`\n:!|_dY*I\x0cHc^0ut"Dzs1"J$Hb9D,Ss LM\ritAp\t\x0cZ[JAN;g\x0cfPJ#Yt@{L=JTzJP\x0b\x0b|AdZB',
#   72),
#  ('VjIv\tnH"te^NNX$X', 16),
#  ("<s]P#D!tE%^0bYEOtT6,\x0b5Qbxp}Fmen`K3t51M'0ge::pa Xp0%<R8'mttRMY0TqM\r5;y3-I{",
#   73),
#  ('H]W?h/%bwd|dy3_i<\x0b[hMq,[EpR$#f*d_Yf$VYmW)HgRwMa+', 48),
#  ('GtWvIZ\x0cQ3V}0)P\r\x0cVsSuwZYitUAK@!/j%^boC%=]f7jH4G<k\x0bXN]oQ"olO6\x0bH\r^%o',
#   65),
#  ('Fn%(|/-Tj>_<"[,r/U4v!:E*~p057hvU];s[^d\n%S?>A^H"^okL*J|UOU[EX8is\ne\njOX{(qL{52PqbQ-+Q(q>0\\h&?!D',
#   93),
#  ('(\'8a:~"\n1qR;\nKDa\t2\x0bu;3.$LjXxe.VzsMN\t#Ht.xb5jE=-+!', 48),
#  ('&ZTEN~3eT', 9),
#  ('\\h\ri3f{Tv4=yxNeIBL;>o\t((7H$)1k"2>xGhIc;*R\r8w,d%9.g!4%sIc*{rm_[tPp:`\tUIky}I)prX',
#   78),
#  ("gz*\\\x0c\x0b0a[FD{F4a;1Bel|zp$)IVbR#'Qfa.XFmBu=", 41),
#  ("]`A421>y9[EE)@A6{v_%hx/7NRz-swE'!V{fSLl%6t{ZN3uaDcngU1\nK", 56),
#  ('Qf&v"AyPTY`7l{&JpvjsCin)w(3nt}R{kv\r*g-^l\tv&\x0cC{ 2}Wp7QlM#NrN\'&"dgb\'1a',
#   68),
#  ('\tv', 2),
#  ("OV]zQI[Ox}9\rk.v q5\r6$8_VvV{\x0c\r[h/=$B1/iI\\JKC#?_wh2Z~p:OHYCUhYB`GI>:MO-P`#C]\n+uoTrx$l$h/%\n'\x0c#?YHxT",
#   96),
#  ('W@&6~owW_82p/dw0rn<m[K;y1][22:lDuO" KJb', 39),
#  ('Te`3\x0bm1/\'yJ qNpEnm"[j;.#Q.=t06T:4???h#aRDG>=<o|7HhE[\tz!Z:Gy?9W\nkd$x*|P:VR\\k',
#   75),
#  ("R\x0bg^[\x0ce-\x0ben\tZB^~c^\rSxze>J$'915:1\x0chfQNZ3E=ha`O?-\ts6qQ36/Pg*~{CQP(7\tV(i*g?q.lb,Y",
#   78),
#  ('ywrP^1>6&\x0c\x0c81>Aj\x0bi\r#heG0 FiG-\n8bLqwVG', 37),
#  ("!Y'&aaEUN\x0cP(Z)S%9si?P$Ei9ij4N?+e\\8&y+CJ\\~ZP.E\t\\<X$It\x0c#4}NKH$0v,9YeLT\x0b<v(3%#e5+J5KnHy!Z\nR",
#   88),
#  ('?', 1),
#  ('u@@Z\t}I^}k5\r Z&[lN`A^-Zr3{W</\\m;UE-FT+\x0b=i$SOuLMBurwu\'.LWu/H<>iFvi\rw)m\'{{/eVZq_n/J:v{b("qBNy$pJQE~25',
#   99),
#  ('p:k*Waw#A_!RE]\t``N6e7Gk\ry', 25),
#  ('}*UD)RZLs]b}a=b#2[-$G~/c+u25c~Db.O{g\x0b,;&pzBkn.shgtx"Ci ;yqah[Qnp.2I\'[Z]g\n ya}`<',
#   79),
#  ("z/ s0iq ,]0Rgi!'5#Es\\mWE\\Ut@>~z]{ocI!yJ'.ArA)O8mMe.@c%h|WiSx~'o\rm 8xUFM$6IN }N)g\x0b{|(+j@4D",
#   89),
#  ("U%\r,RqXqObc'Pf#]X\t@l4ptuc/MQ8)r&pr!boc$g:o),%><T/O?x]Y>=:3II\x0bq`?4pUr%^r0iuWYb:z",
#   79),
#  ('BOG }\\|C\\b;f"L;<@bthQu2!Ai%>L ]ie$FE^}9KopB%`S@} MO4iU9A=[j&o:!Ij-j,Sx rekhU\'Sm4C\nY,',
#   84),
#  ('^K?cc"v%53{', 11),
#  ('.bXx -w`*Mku=f]-~\x0c%k"@=v1si{/]\x0bi>j\r.<m8dzcy<X,\x0cx-R5{9iV7IGw>QN2B@ur\x0cb.}iv%rVE1\rwR-%)g{G|',
#   88),
#  ('@\'NpCcU@>yu?x\x0cDaLiV3N?V6=\x0c\x0bA$<\x0bSX;+\t%ok0ydN{wp!Yx$Pg:"ym_1qHx{{d[3TDF<}oG',
#   73),
#  ('\x0cg?fvJ\r}YUm^JSTQK-db*Vgc1&`N@ZuO>}cR7]B/lCz&f*\\]H0i0b', 53),
#  ('\nHVpvL\\,Xx(lVP1d0dG}qD(e#\x0cCbd(;A 7ve^lUllXx_', 44),
#  ('U{,3*M2fcDa=\x0bMqw}NtX?/', 22),
#  ('*LnS>1.R:tAI$EY=\r X\t|wIy\x0cknsXF?2LY<`A]v2dW~%npN`:G)h4!QXUL1p+q8!g',
#   65),
#  ('b}%_\\)P;zqaS2(Z|\tH 0p;B\r\x0bRV{$`A84bIM?QM?`\r>\x0btA!P)0=T>A]!jP]TO|\x0b.}/CY)LCR-?\x0blI4SUUD8^t',
#   85),
#  ('tM3<Hjn"8\x0ccm:4t@m1@%]T]TmBOUD\'4kZkd[eY~A~DC', 43),
#  ('4.yG\rX87\r@|BsW>D)qM8S55bL0BD704<5j/lY@a-h2\t*hd9{8:\x0c', 50),
#  ('epc!TaeY|V#~l(dhL~S$ga=#4~)vc~ML&F*`,(ODu+_bj:P\x0cK AJ#L210iw ^_q@hne! Z\\gzxh5m[I\tFp=c#',
#   85),
#  ('i=wFo>e<\\_vJP\x0bdz\x0cN*J4>GtO4\nR\'y\x0ckx5\ty}aG@R0\x0c]yt@\x0c{mwL&>el"p+;.9QA',
#   64),
#  (']5x03:kGmPt-)p4?(\noW([V.<GIKe\x0b2RKnZt}^~>\t}=N\r/1\\o;\t"Q\nOkj]SMU }?\trw8`k+0C\tncjwmOw%?RF\'~S!',
#   89),
#  ('fw:Eww}AM:$2"?$#pSy~@\rQ}42R*az|33"]N\'I)Y&U*\t~{Y-n.\n3:JqDT8sc', 60),
#  (':W=g"EU_j!w!H{&}s\x0c5K$x', 22),
#  ("'@/cDg#hi8Ho53!Y9,&6h=X+h+xaCJgXL5Gdc<]eD[D-Kn\x0b0[\nY", 51),
#  ('P>rbRy!T\\"MiSq\rS=\x0boy9hXFKBVHvkXg{Hs"jc\'.:U~Emb[EkyJ[', 52),
#  ('eeMF\rFDG\r0o[@C>nl*kYua|&x{d6M\tbOX![i{i7ej=fP:cAa,-cr\tCPm&V`y\rH=m?Pxmk}ar>%\x0bJ] W[bG%SCW7hIm"s',
#   92),
#  ('8g\rUTcK\nsfFhpu;)E["H.>Z#[y\x0cB2<', 29),
#  ('<nyp#){eDUme6W&&*;+( [MRE:HtG"i%} 3 Zh0a*2h\re7FD\\o\x0b8]6\rt~mKN@&<]LRqO}5/ s+0V 1Rj\x0cp8->gE\n',
#   88),
#  ("B\x0cVH&Q!Gy%CU'GP\\GP\nz`1r|X\nCPS  ^gmZo", 36),
#  ('<o9y##k.n[!fZvTne6%4` ', 22),
#  ('\t}c.hi+q?JKc', 12),
#  ('M!gG,%q:s\r/+U', 13),
#  ('AchRc\to|gm_yz]FlV{H(c\nbO17oHTvGS.fG8Z:"CvN|7IGlb*zW0<=ki *+H^\tW_8NyXA3P3WegCGC',
#   78),
#  ("j!U0:FjR3Cm,kaR\n$V'?\x0chRHg_*K.labvepZ|@o3MGxJ.wU%\t4DVTs\n \tY1%/~O|Hr+IBkm}|zpfJ ",
#   78),
#  ('jCw{<lP3\\9nNQa9]+v\'8rF\tV*|:c\x0blk\x0b:.:6U\x0cxr\'7"92@6/o', 49),
#  ('"\n[p%B, +bjL(0<G@D(s-C', 22),
#  (',Q', 2),
#  ("9Gz\x0bIcC+jJ4}1?/P1TtT+XB0m_,W'8?\x0c1\\5bgON/m~s@)d", 45),
#  ('5OPA', 3),
#  ('M3\\E=R%p$J/v]4R"$=6pHW', 22),
#  ('n+pr4pfB\nFG~Din,}Rz7Me\n+"kMsQ\rNg*=U<_K5?;&tr$P!s,~a(ejlC3Eeg<>&<n(Rw1\rKh5$r|U\\;y\x0cR\x0c7\nv.yoH\\d_y',
#   94),
#  ("LB7x`dJAoHtupo^Mf'w\\lIO3'\\5'T^ew{p$C ad#S])JmifA~ \rBm!Bv'-_u9Zo", 63),
#  ('SyFdhX=I#g8\x0bWP\x0bZE;DZiA5Q_8X.m8\reOtB=dS=-B(3+6P', 46),
#  ('Q&Lt\x0cvk@@de\':iBJ!$vT\x0cj//nHn\r[2Gjd$E:vd \t*d ^Z%;`"AG;bq5>Px${Hs.Hx}\t`8Vg4\\cU{z\rGwU2H~F>vJ~KJ|Mp2',
#   95),
#  ("=-'DP:2(fE3Tibg6[*Bp\n@Kv+a\rs\\TE?>`=A28Wz=Mrk}V1k0l,", 51),
#  ('6bL\x0b6\\ss"wD+L @\'E@\x0b`";#\x0c6vg rtchd5/*b.};TW@VO1 ;\r>&=E{%qg;C)B]P/%\n6W,+vOx*[D fE,{w`$yVVd',
#   87),
#  ('DF_9|TH\t0d|G.d*p,]\\022D\tXe%\\2" uz$Cxp\tP:VZDG1\r,\x0c:/\x0cBdH_bjNWxIz<^\t\x0bs{n)WXxYca',
#   76),
#  ('m)6\x0cwKGK7N\\HmAY5(#CEy\r<=E9I2V<mJ;B_x!0VkvIte?6MUM?/4F3]1Wwr`mXd`\x0b P*7xdh71wS&[\x0c-A8GZ-HxG',
#   88),
#  ('6 %uU%{2]ME5&p| e*v3~\'Ej|u,"("', 29),
#  ("nVxm4K]B H=ztO07\x0b^ch/G+l25'k-jahj)nQN2LAI\x0c+\r2u.1L\x0c\x0bLHb,]", 56)]

# %%
class Evolver(Evolver):
    def selection(self, evaluated_population, tournament_size):
        competition = random.sample(evaluated_population, tournament_size)
        winner = min(competition, key=lambda individual: individual[1])[0]
        # Return a copy of the selected individual
        assert winner
        return winner[:]

# %%
class Evolver(Evolver):
    def crossover(self, parent1, parent2):
        assert parent1
        assert parent2
        pos = random.randint(1, len(parent1))

        offspring1 = parent1[:pos] + parent2[pos:]
        offspring2 = parent2[:pos] + parent1[pos:]
        assert offspring1
        assert offspring2

        return (offspring1, offspring2)

# %%
class Evolver(Evolver):
    def mutate(self, chromosome):
        assert chromosome
        mutated = chromosome[:]
        P = 1.0 / len(mutated)

        for pos in range(len(mutated)):
            if random.random() < P:
                new_c = chr(int(random.gauss(ord(mutated[pos]), 100) % 65536))
                mutated = mutated[:pos] + new_c + mutated[pos + 1:]
        return mutated

# %%
class Evolver(Evolver):
    def genetic_algorithm(self):
        generation = 0
        population = self.create_population(100)
        fitness = self.evaluate_population(population)
        best = min(fitness, key=lambda item: item[1])
        best_individual = best[0]
        best_fitness = best[1]
        if self.log:
            print("Best fitness of initial population: %s - %.10f" % (repr(best_individual), best_fitness))

        # Stop when optimum found, or we run out of patience
        while best_fitness > self.delta and generation < 1000:
            if self.log:
                print('.', best_fitness)
            # The next generation will have the same size as the current one
            new_population = []
            while len(new_population) < len(population):
                # Selection
                offspring1 = self.selection(fitness, 10)
                offspring2 = self.selection(fitness, 10)

                # Crossover
                if random.random() < 0.7:
                    (offspring1, offspring2) = self.crossover(offspring1, offspring2)

                # Mutation
                offspring1 = self.mutate(offspring1)
                offspring2 = self.mutate(offspring2)

                new_population.append(offspring1)
                new_population.append(offspring2)

            # Once full, the new population replaces the old one
            generation += 1
            population = new_population
            fitness = self.evaluate_population(population)

            best = min(fitness, key=lambda item: item[1])
            best_individual = best[0]
            best_fitness = best[1]
            if self.log:
                print("Best fitness at generation %d: %s - %.8f" % (generation, repr(best_individual), best_fitness))

        if self.log:
            print("Best individual: %s, fitness %.10f" %(repr(best_individual), best_fitness))
        return best_individual, best_fitness

# %%
expr_evolver = Evolver(get_expr_fitness)

# %%
expr_evolver.genetic_algorithm()
# Out:
# Best fitness of initial population: '?' - 1.0000000000
# . 1
# Best fitness at generation 1: 'S' - 1.00000000
# . 1
# Best fitness at generation 2: 'Ü' - 1.00000000
# . 1
# Best fitness at generation 3: 'Î' - 1.00000000
# . 1
# Best fitness at generation 4: 'Ę' - 1.00000000
# . 1
# Best fitness at generation 5: 'ﾞ' - 1.00000000
# . 1
# Best fitness at generation 6: '`' - 1.00000000
# . 1
# Best fitness at generation 7: 'ﻰ' - 1.00000000
# . 1
# Best fitness at generation 8: 'ﻃ' - 1.00000000
# . 1
# Best fitness at generation 9: 'C' - 1.00000000
# . 1
# Best fitness at generation 10: 'Ƈ' - 1.00000000
# . 1
# Best fitness at generation 11: ' ' - 1.00000000
# . 1
# Best fitness at generation 12: 'ź' - 1.00000000
# . 1
# Best fitness at generation 13: '\ufff8' - 1.00000000
# . 1
# Best fitness at generation 14: 'ﾸ' - 1.00000000
# . 1
# Best fitness at generation 15: 'Ǫ' - 1.00000000
# . 1
# Best fitness at generation 16: 'ē' - 1.00000000
# . 1
# Best fitness at generation 17: 'ā' - 1.00000000
# . 1
# Best fitness at generation 18: 'ŵ' - 1.00000000
# . 1
# Best fitness at generation 19: 'ﻹ' - 1.00000000
# . 1
# Best fitness at generation 20: 'ﺛ' - 1.00000000
# . 1
# Best fitness at generation 21: 'Ʊ' - 1.00000000
# . 1
# Best fitness at generation 22: '\x06' - 1.00000000
# . 1
# Best fitness at generation 23: 'ﻖ' - 1.00000000
# . 1
# Best fitness at generation 24: '﹩' - 1.00000000
# . 1
# Best fitness at generation 25: '¼' - 1.00000000
# . 1
# Best fitness at generation 26: '̾' - 1.00000000
# . 1
# Best fitness at generation 27: 'ƈ' - 1.00000000
# . 1
# Best fitness at generation 28: '˴' - 1.00000000
# . 1
# Best fitness at generation 29: 'Ɛ' - 1.00000000
# . 1
# Best fitness at generation 30: 'Ԥ' - 1.00000000
# . 1
# Best fitness at generation 31: 'Ɵ' - 1.00000000
# . 1
# Best fitness at generation 32: 'Ҡ' - 1.00000000
# . 1
# Best fitness at generation 33: '＞' - 1.00000000
# . 1
# Best fitness at generation 34: 'ȑ' - 1.00000000
# . 1
# Best fitness at generation 35: 'ｆ' - 1.00000000
# . 1
# Best fitness at generation 36: 'Ϟ' - 1.00000000
# . 1
# Best fitness at generation 37: 'Ƭ' - 1.00000000
# . 1
# Best fitness at generation 38: 'Ѫ' - 1.00000000
# . 1
# Best fitness at generation 39: '\ufdd3' - 1.00000000
# . 1
# Best fitness at generation 40: '˶' - 1.00000000
# . 1
# Best fitness at generation 41: 'ͥ' - 1.00000000
# . 1
# Best fitness at generation 42: 'ˢ' - 1.00000000
# . 1
# Best fitness at generation 43: '̍' - 1.00000000
# . 1
# Best fitness at generation 44: '\uffde' - 1.00000000
# . 1
# Best fitness at generation 45: '৷' - 1.00000000
# . 1
# Best fitness at generation 46: 'ӈ' - 1.00000000
# . 1
# Best fitness at generation 47: 'ࣇ' - 1.00000000
# . 1
# Best fitness at generation 48: 'ʾ' - 1.00000000
# . 1
# Best fitness at generation 49: 'ʿ' - 1.00000000
# . 1
# Best fitness at generation 50: '͞' - 1.00000000
# . 1
# Best fitness at generation 51: 'ï' - 1.00000000
# . 1
# Best fitness at generation 52: 'ޥ' - 1.00000000
# . 1
# Best fitness at generation 53: 'ϳ' - 1.00000000
# . 1
# Best fitness at generation 54: 'ঙ' - 1.00000000
# . 1
# Best fitness at generation 55: 'Ȋ' - 1.00000000
# . 1
# Best fitness at generation 56: 'Ҳ' - 1.00000000
# . 1
# Best fitness at generation 57: 'Ѐ' - 1.00000000
# . 1
# Best fitness at generation 58: 'ͷ' - 1.00000000
# . 1
# Best fitness at generation 59: '̣' - 1.00000000
# . 1
# Best fitness at generation 60: 'ࢽ' - 1.00000000
# . 1
# Best fitness at generation 61: '̛' - 1.00000000
# . 1
# Best fitness at generation 62: 'ࠒ' - 1.00000000
# . 1
# Best fitness at generation 63: 'ܡ' - 1.00000000
# . 1
# Best fitness at generation 64: 'ِ' - 1.00000000
# . 1
# Best fitness at generation 65: '\u03a2' - 1.00000000
# . 1
# Best fitness at generation 66: 'ܧ' - 1.00000000
# . 1
# Best fitness at generation 67: 'Վ' - 1.00000000
# . 1
# Best fitness at generation 68: 'ۛ' - 1.00000000
# . 1
# Best fitness at generation 69: 'ﴮ' - 1.00000000
# . 1
# Best fitness at generation 70: 'ت' - 1.00000000
# . 1
# Best fitness at generation 71: 'ӌ' - 1.00000000
# . 1
# Best fitness at generation 72: 'ۧ' - 1.00000000
# . 1
# Best fitness at generation 73: 'Ȋ' - 1.00000000
# . 1
# Best fitness at generation 74: '̾' - 1.00000000
# . 1
# Best fitness at generation 75: 'ߢ' - 1.00000000
# . 1
# Best fitness at generation 76: 'א' - 1.00000000
# . 1
# Best fitness at generation 77: 'Ά' - 1.00000000
# . 1
# Best fitness at generation 78: 'Ĩ' - 1.00000000
# . 1
# Best fitness at generation 79: 'Ը' - 1.00000000
# . 1
# Best fitness at generation 80: 'ध' - 1.00000000
# . 1
# Best fitness at generation 81: 'э' - 1.00000000
# . 1
# Best fitness at generation 82: 'Μ' - 1.00000000
# . 1
# Best fitness at generation 83: 'ｃ' - 1.00000000
# . 1
# Best fitness at generation 84: 'е' - 1.00000000
# . 1
# Best fitness at generation 85: 'Պ' - 1.00000000
# . 1
# Best fitness at generation 86: 'ь' - 1.00000000
# . 1
# Best fitness at generation 87: '͂' - 1.00000000
# . 1
# Best fitness at generation 88: '͈' - 1.00000000
# . 1
# Best fitness at generation 89: 'ؿ' - 1.00000000
# . 1
# Best fitness at generation 90: 'ҳ' - 1.00000000
# . 1
# Best fitness at generation 91: '-' - 1.00000000
# . 1
# Best fitness at generation 92: 'ϩ' - 1.00000000
# . 1
# Best fitness at generation 93: 'Ż' - 1.00000000
# . 1
# Best fitness at generation 94: 'Ɯ' - 1.00000000
# . 1
# Best fitness at generation 95: '\u0604' - 1.00000000
# . 1
# Best fitness at generation 96: 'ੴ' - 1.00000000
# . 1
# Best fitness at generation 97: '߄' - 1.00000000
# . 1
# Best fitness at generation 98: '΄' - 1.00000000
# . 1
# Best fitness at generation 99: 'ଝ' - 1.00000000
# . 1
# Best fitness at generation 100: '̣' - 1.00000000
# . 1
# Best fitness at generation 101: 'Ͻ' - 1.00000000
# . 1
# Best fitness at generation 102: 'Ζ' - 1.00000000
# . 1
# Best fitness at generation 103: 'Ֆ' - 1.00000000
# . 1
# Best fitness at generation 104: '̱' - 1.00000000
# . 1
# Best fitness at generation 105: 'ŷ' - 1.00000000
# . 1
# Best fitness at generation 106: 'Ц' - 1.00000000
# . 1
# Best fitness at generation 107: 'ԗ' - 1.00000000
# . 1
# Best fitness at generation 108: 'ʶ' - 1.00000000
# . 1
# Best fitness at generation 109: '˵' - 1.00000000
# . 1
# Best fitness at generation 110: 'ȱ' - 1.00000000
# . 1
# Best fitness at generation 111: 'ɳ' - 1.00000000
# . 1
# Best fitness at generation 112: '\ufd40' - 1.00000000
# . 1
# Best fitness at generation 113: 'ˎ' - 1.00000000
# . 1
# Best fitness at generation 114: 'ƍ' - 1.00000000
# . 1
# Best fitness at generation 115: 'ƍ' - 1.00000000
# . 1
# Best fitness at generation 116: 'Ї' - 1.00000000
# . 1
# Best fitness at generation 117: 'Ɏ' - 1.00000000
# . 1
# Best fitness at generation 118: 'ʈ' - 1.00000000
# . 1
# Best fitness at generation 119: 'Ӈ' - 1.00000000
# . 1
# Best fitness at generation 120: 'ڥ' - 1.00000000
# . 1
# Best fitness at generation 121: 'ӊ' - 1.00000000
# . 1
# Best fitness at generation 122: '¸' - 1.00000000
# . 1
# Best fitness at generation 123: 'ȸ' - 1.00000000
# . 1
# Best fitness at generation 124: 'ѿ' - 1.00000000
# . 1
# Best fitness at generation 125: 'њ' - 1.00000000
# . 1
# Best fitness at generation 126: '̀' - 1.00000000
# . 1
# Best fitness at generation 127: 'ϭ' - 1.00000000
# . 1
# Best fitness at generation 128: 'х' - 1.00000000
# . 1
# Best fitness at generation 129: 'ȍ' - 1.00000000
# . 1
# Best fitness at generation 130: 'ϲ' - 1.00000000
# . 1
# Best fitness at generation 131: 'ǥ' - 1.00000000
# . 1
# Best fitness at generation 132: 'Њ' - 1.00000000
# . 1
# Best fitness at generation 133: 'ӯ' - 1.00000000
# . 1
# Best fitness at generation 134: 'ٲ' - 1.00000000
# . 1
# Best fitness at generation 135: '\x12' - 1.00000000
# . 1
# Best fitness at generation 136: '֓' - 1.00000000
# . 1
# Best fitness at generation 137: 'Ϸ' - 1.00000000
# . 1
# Best fitness at generation 138: 'ɗ' - 1.00000000
# . 1
# Best fitness at generation 139: '︺' - 1.00000000
# . 1
# Best fitness at generation 140: 'ʒ' - 1.00000000
# . 1
# Best fitness at generation 141: 'Č' - 1.00000000
# . 1
# Best fitness at generation 142: 'Ϸ' - 1.00000000
# . 1
# Best fitness at generation 143: 'ژ' - 1.00000000
# . 1
# Best fitness at generation 144: 'ϫ' - 1.00000000
# . 1
# Best fitness at generation 145: 'ـ' - 1.00000000
# . 1
# Best fitness at generation 146: '0' - 1.00000000
# . 1.0
# Best fitness at generation 147: 'ك' - 1.00000000
# . 1
# Best fitness at generation 148: '\x1b' - 1.00000000
# . 1
# Best fitness at generation 149: 'ׅ' - 1.00000000
# . 1
# Best fitness at generation 150: 'Ɇ' - 1.00000000
# . 1
# Best fitness at generation 151: 'Ǒ' - 1.00000000
# . 1
# Best fitness at generation 152: 'Ϝ' - 1.00000000
# . 1
# Best fitness at generation 153: 'μ' - 1.00000000
# . 1
# Best fitness at generation 154: 'ĵ' - 1.00000000
# . 1
# Best fitness at generation 155: 'ǚ' - 1.00000000
# . 1
# Best fitness at generation 156: '\u089a' - 1.00000000
# . 1
# Best fitness at generation 157: 'Ҹ' - 1.00000000
# . 1
# Best fitness at generation 158: 'т' - 1.00000000
# . 1
# Best fitness at generation 159: '\x87' - 1.00000000
# . 1
# Best fitness at generation 160: 'ģ' - 1.00000000
# . 1
# Best fitness at generation 161: 'Ś' - 1.00000000
# . 1
# Best fitness at generation 162: 'ɭ' - 1.00000000
# . 1
# Best fitness at generation 163: '̛' - 1.00000000
# . 1
# Best fitness at generation 164: 'ܺ' - 1.00000000
# . 1
# Best fitness at generation 165: '\n' - 1.00000000
# . 1
# Best fitness at generation 166: 'Ɉ' - 1.00000000
# . 1
# Best fitness at generation 167: 'Ʊ' - 1.00000000
# . 1
# Best fitness at generation 168: '\ufe67' - 1.00000000
# . 1
# Best fitness at generation 169: 'Ɗ' - 1.00000000
# . 1
# Best fitness at generation 170: '\u05f8' - 1.00000000
# . 1
# Best fitness at generation 171: 'Ż' - 1.00000000
# . 1
# Best fitness at generation 172: '˭' - 1.00000000
# . 1
# Best fitness at generation 173: 'Ȓ' - 1.00000000
# . 1
# Best fitness at generation 174: 'ѩ' - 1.00000000
# . 1
# Best fitness at generation 175: 'ﻙ' - 1.00000000
# . 1
# Best fitness at generation 176: 't' - 1.00000000
# . 1
# Best fitness at generation 177: '̉' - 1.00000000
# . 1
# Best fitness at generation 178: '߮' - 1.00000000
# . 1
# Best fitness at generation 179: 'x' - 1.00000000
# . 1
# Best fitness at generation 180: 'c' - 1.00000000
# . 1
# Best fitness at generation 181: 'ò' - 1.00000000
# . 1
# Best fitness at generation 182: '̦' - 1.00000000
# . 1
# Best fitness at generation 183: 'ϔ' - 1.00000000
# . 1
# Best fitness at generation 184: 'Ѕ' - 1.00000000
# . 1
# Best fitness at generation 185: 'ｩ' - 1.00000000
# . 1
# Best fitness at generation 186: 'ˬ' - 1.00000000
# . 1
# Best fitness at generation 187: 'Ҿ' - 1.00000000
# . 1
# Best fitness at generation 188: '1' - 1.00000000
# . 1.0
# Best fitness at generation 189: '\u0a63' - 1.00000000
# . 1
# Best fitness at generation 190: '͒' - 1.00000000
# . 1
# Best fitness at generation 191: 'ȟ' - 1.00000000
# . 1
# Best fitness at generation 192: '\x1b' - 1.00000000
# . 1
# Best fitness at generation 193: '̛' - 1.00000000
# . 1
# Best fitness at generation 194: 'ǁ' - 1.00000000
# . 1
# Best fitness at generation 195: 'ࡘ' - 1.00000000
# . 1
# Best fitness at generation 196: 'ŋ' - 1.00000000
# . 1
# Best fitness at generation 197: 'ˋ' - 1.00000000
# . 1
# Best fitness at generation 198: '!' - 1.00000000
# . 1
# Best fitness at generation 199: '\x0c' - 1.00000000
# . 1
# Best fitness at generation 200: 'ﺺ' - 1.00000000
# . 1
# Best fitness at generation 201: 'ￋ' - 1.00000000
# . 1
# Best fitness at generation 202: 'Ȁ' - 1.00000000
# . 1
# Best fitness at generation 203: 'Ɋ' - 1.00000000
# . 1
# Best fitness at generation 204: '̩' - 1.00000000
# . 1
# Best fitness at generation 205: '\x9e' - 1.00000000
# . 1
# Best fitness at generation 206: 'ڸ' - 1.00000000
# . 1
# Best fitness at generation 207: 'ʁ' - 1.00000000
# . 1
# Best fitness at generation 208: 'Ɩ' - 1.00000000
# . 1
# Best fitness at generation 209: 'Ā' - 1.00000000
# . 1
# Best fitness at generation 210: 'Â' - 1.00000000
# . 1
# Best fitness at generation 211: 'ϧ' - 1.00000000
# . 1
# Best fitness at generation 212: 'Å' - 1.00000000
# . 1
# Best fitness at generation 213: 'Ӗ' - 1.00000000
# . 1
# Best fitness at generation 214: '̙' - 1.00000000
# . 1
# Best fitness at generation 215: '\x91' - 1.00000000
# . 1
# Best fitness at generation 216: 'ޞ' - 1.00000000
# . 1
# Best fitness at generation 217: 'W' - 1.00000000
# . 1
# Best fitness at generation 218: 'γ' - 1.00000000
# . 1
# Best fitness at generation 219: '϶' - 1.00000000
# . 1
# Best fitness at generation 220: 'ȉ' - 1.00000000
# . 1
# Best fitness at generation 221: '˹' - 1.00000000
# . 1
# Best fitness at generation 222: 'p' - 1.00000000
# . 1
# Best fitness at generation 223: 'া' - 1.00000000
# . 1
# Best fitness at generation 224: 'Ȩ' - 1.00000000
# . 1
# Best fitness at generation 225: 'ǝ' - 1.00000000
# . 1
# Best fitness at generation 226: 'Ǳ' - 1.00000000
# . 1
# Best fitness at generation 227: 'ޯ' - 1.00000000
# . 1
# Best fitness at generation 228: '˹' - 1.00000000
# . 1
# Best fitness at generation 229: 'ْ' - 1.00000000
# . 1
# Best fitness at generation 230: '׳' - 1.00000000
# . 1
# Best fitness at generation 231: 'ۢ' - 1.00000000
# . 1
# Best fitness at generation 232: 'ۛ' - 1.00000000
# . 1
# Best fitness at generation 233: 'ũ' - 1.00000000
# . 1
# Best fitness at generation 234: '\u0590' - 1.00000000
# . 1
# Best fitness at generation 235: '\x80' - 1.00000000
# . 1
# Best fitness at generation 236: '۪' - 1.00000000
# . 1
# Best fitness at generation 237: 'і' - 1.00000000
# . 1
# Best fitness at generation 238: 'પ' - 1.00000000
# . 1
# Best fitness at generation 239: 'ǩ' - 1.00000000
# . 1
# Best fitness at generation 240: 'Ŷ' - 1.00000000
# . 1
# Best fitness at generation 241: 'ɶ' - 1.00000000
# . 1
# Best fitness at generation 242: 'ͽ' - 1.00000000
# . 1
# Best fitness at generation 243: '\u05cb' - 1.00000000
# . 1
# Best fitness at generation 244: 'Ϙ' - 1.00000000
# . 1
# Best fitness at generation 245: 'Ā' - 1.00000000
# . 1
# Best fitness at generation 246: 'Ԃ' - 1.00000000
# . 1
# Best fitness at generation 247: 'Ω' - 1.00000000
# . 1
# Best fitness at generation 248: '¸' - 1.00000000
# . 1
# Best fitness at generation 249: '@' - 1.00000000
# . 1
# Best fitness at generation 250: 'Þ' - 1.00000000
# . 1
# Best fitness at generation 251: 'ɶ' - 1.00000000
# . 1
# Best fitness at generation 252: '\u0382' - 1.00000000
# . 1
# Best fitness at generation 253: 'ӡ' - 1.00000000
# . 1
# Best fitness at generation 254: 'ӽ' - 1.00000000
# . 1
# Best fitness at generation 255: 'ε' - 1.00000000
# . 1
# Best fitness at generation 256: 'ӿ' - 1.00000000
# . 1
# Best fitness at generation 257: 'Ѣ' - 1.00000000
# . 1
# Best fitness at generation 258: 'θ' - 1.00000000
# . 1
# Best fitness at generation 259: 'ﺗ' - 1.00000000
# . 1
# Best fitness at generation 260: 'ξ' - 1.00000000
# . 1
# Best fitness at generation 261: 'ʖ' - 1.00000000
# . 1
# Best fitness at generation 262: 'ԓ' - 1.00000000
# . 1
# Best fitness at generation 263: '\u086d' - 1.00000000
# . 1
# Best fitness at generation 264: 'Э' - 1.00000000
# . 1
# Best fitness at generation 265: '۠' - 1.00000000
# . 1
# Best fitness at generation 266: '\u0530' - 1.00000000
# . 1
# Best fitness at generation 267: 'Č' - 1.00000000
# . 1
# Best fitness at generation 268: 'Ձ' - 1.00000000
# . 1
# Best fitness at generation 269: '݃' - 1.00000000
# . 1
# Best fitness at generation 270: '̝' - 1.00000000
# . 1
# Best fitness at generation 271: 'Ϫ' - 1.00000000
# . 1
# Best fitness at generation 272: '͊' - 1.00000000
# . 1
# Best fitness at generation 273: 'А' - 1.00000000
# . 1
# Best fitness at generation 274: 'Տ' - 1.00000000
# . 1
# Best fitness at generation 275: 'Ư' - 1.00000000
# . 1
# Best fitness at generation 276: 'ǭ' - 1.00000000
# . 1
# Best fitness at generation 277: 'Ʀ' - 1.00000000
# . 1
# Best fitness at generation 278: '̂' - 1.00000000
# . 1
# Best fitness at generation 279: 'Չ' - 1.00000000
# . 1
# Best fitness at generation 280: 'ӌ' - 1.00000000
# . 1
# Best fitness at generation 281: 'ǟ' - 1.00000000
# . 1
# Best fitness at generation 282: 'Д' - 1.00000000
# . 1
# Best fitness at generation 283: 'ם' - 1.00000000
# . 1
# Best fitness at generation 284: 'ȸ' - 1.00000000
# . 1
# Best fitness at generation 285: '﹐' - 1.00000000
# . 1
# Best fitness at generation 286: 'Ϗ' - 1.00000000
# . 1
# Best fitness at generation 287: '﹐' - 1.00000000
# . 1
# Best fitness at generation 288: '͏' - 1.00000000
# . 1
# Best fitness at generation 289: 'ﺐ' - 1.00000000
# . 1
# Best fitness at generation 290: 'Ϥ' - 1.00000000
# . 1
# Best fitness at generation 291: 'Ѳ' - 1.00000000
# . 1
# Best fitness at generation 292: 'ա' - 1.00000000
# . 1
# Best fitness at generation 293: '̇' - 1.00000000
# . 1
# Best fitness at generation 294: 'w' - 1.00000000
# . 1
# Best fitness at generation 295: 'ә' - 1.00000000
# . 1
# Best fitness at generation 296: 'ﲢ' - 1.00000000
# . 1
# Best fitness at generation 297: 'Υ' - 1.00000000
# . 1
# Best fitness at generation 298: 'ۗ' - 1.00000000
# . 1
# Best fitness at generation 299: '\\' - 1.00000000
# . 1
# Best fitness at generation 300: 'ڳ' - 1.00000000
# . 1
# Best fitness at generation 301: 'Ò' - 1.00000000
# . 1
# Best fitness at generation 302: 'ϛ' - 1.00000000
# . 1
# Best fitness at generation 303: 'ﳽ' - 1.00000000
# . 1
# Best fitness at generation 304: 'Ɨ' - 1.00000000
# . 1
# Best fitness at generation 305: 'ҙ' - 1.00000000
# . 1
# Best fitness at generation 306: 'ߨ' - 1.00000000
# . 1
# Best fitness at generation 307: 'Ғ' - 1.00000000
# . 1
# Best fitness at generation 308: 'ӂ' - 1.00000000
# . 1
# Best fitness at generation 309: 'ￜ' - 1.00000000
# . 1
# Best fitness at generation 310: 'ҵ' - 1.00000000
# . 1
# Best fitness at generation 311: 'ց' - 1.00000000
# . 1
# Best fitness at generation 312: 'ﺳ' - 1.00000000
# . 1
# Best fitness at generation 313: 'ﱦ' - 1.00000000
# . 1
# Best fitness at generation 314: '\u0603' - 1.00000000
# . 1
# Best fitness at generation 315: 'Ѵ' - 1.00000000
# . 1
# Best fitness at generation 316: 'ﰓ' - 1.00000000
# . 1
# Best fitness at generation 317: 'Ҍ' - 1.00000000
# . 1
# Best fitness at generation 318: '׆' - 1.00000000
# . 1
# Best fitness at generation 319: 'ﹻ' - 1.00000000
# . 1
# Best fitness at generation 320: '﹙' - 1.00000000
# . 1
# Best fitness at generation 321: 'ַ' - 1.00000000
# . 1
# Best fitness at generation 322: 'ﮱ' - 1.00000000
# . 1
# Best fitness at generation 323: '﮾' - 1.00000000
# . 1
# Best fitness at generation 324: 'ԏ' - 1.00000000
# . 1
# Best fitness at generation 325: '\u05fe' - 1.00000000
# . 1
# Best fitness at generation 326: 'ڔ' - 1.00000000
# . 1
# Best fitness at generation 327: '﹚' - 1.00000000
# . 1
# Best fitness at generation 328: 'ࡨ' - 1.00000000
# . 1
# Best fitness at generation 329: 'ר' - 1.00000000
# . 1
# Best fitness at generation 330: 'ѳ' - 1.00000000
# . 1
# Best fitness at generation 331: '֯' - 1.00000000
# . 1
# Best fitness at generation 332: 'ӆ' - 1.00000000
# . 1
# Best fitness at generation 333: '˵' - 1.00000000
# . 1
# Best fitness at generation 334: 'ﺢ' - 1.00000000
# . 1
# Best fitness at generation 335: 'ߝ' - 1.00000000
# . 1
# Best fitness at generation 336: 'і' - 1.00000000
# . 1
# Best fitness at generation 337: 'ﶹ' - 1.00000000
# . 1
# Best fitness at generation 338: 'ȸ' - 1.00000000
# . 1
# Best fitness at generation 339: 'ӛ' - 1.00000000
# . 1
# Best fitness at generation 340: 'ࢤ' - 1.00000000
# . 1
# Best fitness at generation 341: '．' - 1.00000000
# . 1
# Best fitness at generation 342: 'ٱ' - 1.00000000
# . 1
# Best fitness at generation 343: 'Ｌ' - 1.00000000
# . 1
# Best fitness at generation 344: 'ｃ' - 1.00000000
# . 1
# Best fitness at generation 345: '\ufdd8' - 1.00000000
# . 1
# Best fitness at generation 346: '^' - 1.00000000
# . 1
# Best fitness at generation 347: 'Ý' - 1.00000000
# . 1
# Best fitness at generation 348: '﹒' - 1.00000000
# . 1
# Best fitness at generation 349: 'ￊ' - 1.00000000
# . 1
# Best fitness at generation 350: 'ߍ' - 1.00000000
# . 1
# Best fitness at generation 351: 'ￆ' - 1.00000000
# . 1
# Best fitness at generation 352: 'ǎ' - 1.00000000
# . 1
# Best fitness at generation 353: 'ﰩ' - 1.00000000
# . 1
# Best fitness at generation 354: 'W' - 1.00000000
# . 1
# Best fitness at generation 355: '\ufff4' - 1.00000000
# . 1
# Best fitness at generation 356: 'ﱒ' - 1.00000000
# . 1
# Best fitness at generation 357: 'Ｍ' - 1.00000000
# . 1
# Best fitness at generation 358: 'Ɠ' - 1.00000000
# . 1
# Best fitness at generation 359: '︄' - 1.00000000
# . 1
# Best fitness at generation 360: '\ufafe' - 1.00000000
# . 1
# Best fitness at generation 361: 'ﮢ' - 1.00000000
# . 1
# Best fitness at generation 362: '\ufbc4' - 1.00000000
# . 1
# Best fitness at generation 363: '︖' - 1.00000000
# . 1
# Best fitness at generation 364: 'ͅ' - 1.00000000
# . 1
# Best fitness at generation 365: 'ﾉ' - 1.00000000
# . 1
# Best fitness at generation 366: 'Ƀ' - 1.00000000
# . 1
# Best fitness at generation 367: 'u' - 1.00000000
# . 1
# Best fitness at generation 368: 'ͷ' - 1.00000000
# . 1
# Best fitness at generation 369: 'ǿ' - 1.00000000
# . 1
# Best fitness at generation 370: '﹡' - 1.00000000
# . 1
# Best fitness at generation 371: 'Ȋ' - 1.00000000
# . 1
# Best fitness at generation 372: '\x7f' - 1.00000000
# . 1
# Best fitness at generation 373: 'ü' - 1.00000000
# . 1
# Best fitness at generation 374: 'ﻯ' - 1.00000000
# . 1
# Best fitness at generation 375: 'Ζ' - 1.00000000
# . 1
# Best fitness at generation 376: 'ȗ' - 1.00000000
# . 1
# Best fitness at generation 377: 'ﭤ' - 1.00000000
# . 1
# Best fitness at generation 378: 'ﻥ' - 1.00000000
# . 1
# Best fitness at generation 379: 'ǀ' - 1.00000000
# . 1
# Best fitness at generation 380: 'ƹ' - 1.00000000
# . 1
# Best fitness at generation 381: 'ʷ' - 1.00000000
# . 1
# Best fitness at generation 382: 'ａ' - 1.00000000
# . 1
# Best fitness at generation 383: '\ufff6' - 1.00000000
# . 1
# Best fitness at generation 384: 'Ý' - 1.00000000
# . 1
# Best fitness at generation 385: 'ﰯ' - 1.00000000
# . 1
# Best fitness at generation 386: 'U' - 1.00000000
# . 1
# Best fitness at generation 387: 'ﳟ' - 1.00000000
# . 1
# Best fitness at generation 388: 's' - 1.00000000
# . 1
# Best fitness at generation 389: '~' - 1.00000000
# . 1
# Best fitness at generation 390: 'ƙ' - 1.00000000
# . 1
# Best fitness at generation 391: 'ﱶ' - 1.00000000
# . 1
# Best fitness at generation 392: '×' - 1.00000000
# . 1
# Best fitness at generation 393: 'ﱁ' - 1.00000000
# . 1
# Best fitness at generation 394: 'ﴵ' - 1.00000000
# . 1
# Best fitness at generation 395: '}' - 1.00000000
# . 1
# Best fitness at generation 396: 'n' - 1.00000000
# . 1
# Best fitness at generation 397: '５' - 1.00000000
# . 1
# Best fitness at generation 398: 'ﰫ' - 1.00000000
# . 1
# Best fitness at generation 399: 'ʤ' - 1.00000000
# . 1
# Best fitness at generation 400: '缾' - 1.00000000
# . 1
# Best fitness at generation 401: '\ufd47' - 1.00000000
# . 1
# Best fitness at generation 402: '\ufddc' - 1.00000000
# . 1
# Best fitness at generation 403: 'ﳲ' - 1.00000000
# . 1
# Best fitness at generation 404: '彩' - 1.00000000
# . 1
# Best fitness at generation 405: 'ｩ' - 1.00000000
# . 1
# Best fitness at generation 406: '\ufaea' - 1.00000000
# . 1
# Best fitness at generation 407: 'ﯸ' - 1.00000000
# . 1
# Best fitness at generation 408: '\ufe1a' - 1.00000000
# . 1
# Best fitness at generation 409: 'ﺝ' - 1.00000000
# . 1
# Best fitness at generation 410: 'ﻼ' - 1.00000000
# . 1
# Best fitness at generation 411: 'ﺽ' - 1.00000000
# . 1
# Best fitness at generation 412: 'ﰰ' - 1.00000000
# . 1
# Best fitness at generation 413: '愈' - 1.00000000
# . 1
# Best fitness at generation 414: 'ﰮ' - 1.00000000
# . 1
# Best fitness at generation 415: 'ƈ' - 1.00000000
# . 1
# Best fitness at generation 416: 'ﳛ' - 1.00000000
# . 1
# Best fitness at generation 417: 'ﭏ' - 1.00000000
# . 1
# Best fitness at generation 418: 'ы' - 1.00000000
# . 1
# Best fitness at generation 419: '龜' - 1.00000000
# . 1
# Best fitness at generation 420: 'Ί' - 1.00000000
# . 1
# Best fitness at generation 421: '﹇' - 1.00000000
# . 1
# Best fitness at generation 422: '\uf83e' - 1.00000000
# . 1
# Best fitness at generation 423: '︻' - 1.00000000
# . 1
# Best fitness at generation 424: '̎' - 1.00000000
# . 1
# Best fitness at generation 425: '\uf8fa' - 1.00000000
# . 1
# Best fitness at generation 426: '\uf7c2' - 1.00000000
# . 1
# Best fitness at generation 427: 'ﻆ' - 1.00000000
# . 1
# Best fitness at generation 428: 'לּ' - 1.00000000
# . 1
# Best fitness at generation 429: '\x1a' - 1.00000000
# . 1
# Best fitness at generation 430: '便' - 1.00000000
# . 1
# Best fitness at generation 431: 'ш' - 1.00000000
# . 1
# Best fitness at generation 432: 'ﰐ' - 1.00000000
# . 1
# Best fitness at generation 433: '￫' - 1.00000000
# . 1
# Best fitness at generation 434: 'ų' - 1.00000000
# . 1
# Best fitness at generation 435: '˃' - 1.00000000
# . 1
# Best fitness at generation 436: 'ﺆ' - 1.00000000
# . 1
# Best fitness at generation 437: 'ﶳ' - 1.00000000
# . 1
# Best fitness at generation 438: '\uf5d3' - 1.00000000
# . 1
# Best fitness at generation 439: '\uf88b' - 1.00000000
# . 1
# Best fitness at generation 440: '窱' - 1.00000000
# . 1
# Best fitness at generation 441: '\uf84e' - 1.00000000
# . 1
# Best fitness at generation 442: '\ufae1' - 1.00000000
# . 1
# Best fitness at generation 443: 'ｎ' - 1.00000000
# . 1
# Best fitness at generation 444: 'Ú' - 1.00000000
# . 1
# Best fitness at generation 445: '\x86' - 1.00000000
# . 1
# Best fitness at generation 446: 'ƅ' - 1.00000000
# . 1
# Best fitness at generation 447: 'ﶣ' - 1.00000000
# . 1
# Best fitness at generation 448: '３' - 1.00000000
# . 1
# Best fitness at generation 449: 'Ɏ' - 1.00000000
# . 1
# Best fitness at generation 450: '\ufddc' - 1.00000000
# . 1
# Best fitness at generation 451: 'ﻅ' - 1.00000000
# . 1
# Best fitness at generation 452: 'ã' - 1.00000000
# . 1
# Best fitness at generation 453: '\x1a' - 1.00000000
# . 1
# Best fitness at generation 454: 'ﴽ' - 1.00000000
# . 1
# Best fitness at generation 455: '͐' - 1.00000000
# . 1
# Best fitness at generation 456: '\uf7f6' - 1.00000000
# . 1
# Best fitness at generation 457: '˻' - 1.00000000
# . 1
# Best fitness at generation 458: 'ʞ' - 1.00000000
# . 1
# Best fitness at generation 459: 'ﵳ' - 1.00000000
# . 1
# Best fitness at generation 460: 'ﵗ' - 1.00000000
# . 1
# Best fitness at generation 461: 'ͪ' - 1.00000000
# . 1
# Best fitness at generation 462: '\ufd49' - 1.00000000
# . 1
# Best fitness at generation 463: 'ﳵ' - 1.00000000
# . 1
# Best fitness at generation 464: 'ﹱ' - 1.00000000
# . 1
# Best fitness at generation 465: 'ﵒ' - 1.00000000
# . 1
# Best fitness at generation 466: '̔' - 1.00000000
# . 1
# Best fitness at generation 467: 'ʅ' - 1.00000000
# . 1
# Best fitness at generation 468: 'ﻻ' - 1.00000000
# . 1
# Best fitness at generation 469: '\x08' - 1.00000000
# . 1
# Best fitness at generation 470: 'ɗ' - 1.00000000
# . 1
# Best fitness at generation 471: 'ǰ' - 1.00000000
# . 1
# Best fitness at generation 472: 'ﻟ' - 1.00000000
# . 1
# Best fitness at generation 473: 'ﰝ' - 1.00000000
# . 1
# Best fitness at generation 474: '̥' - 1.00000000
# . 1
# Best fitness at generation 475: 'ɑ' - 1.00000000
# . 1
# Best fitness at generation 476: 'ﶘ' - 1.00000000
# . 1
# Best fitness at generation 477: '֚' - 1.00000000
# . 1
# Best fitness at generation 478: 'ﱻ' - 1.00000000
# . 1
# Best fitness at generation 479: '͈' - 1.00000000
# . 1
# Best fitness at generation 480: 'ﺉ' - 1.00000000
# . 1
# Best fitness at generation 481: 'ﵶ' - 1.00000000
# . 1
# Best fitness at generation 482: '謁' - 1.00000000
# . 1
# Best fitness at generation 483: 'ﻔ' - 1.00000000
# . 1
# Best fitness at generation 484: 'Ƶ' - 1.00000000
# . 1
# Best fitness at generation 485: 'ə' - 1.00000000
# . 1
# Best fitness at generation 486: 'ﴤ' - 1.00000000
# . 1
# Best fitness at generation 487: 'ﱡ' - 1.00000000
# . 1
# Best fitness at generation 488: '\ufdd2' - 1.00000000
# . 1
# Best fitness at generation 489: 'ﳙ' - 1.00000000
# . 1
# Best fitness at generation 490: '\x0b' - 1.00000000
# . 1
# Best fitness at generation 491: '·' - 1.00000000
# . 1
# Best fitness at generation 492: 'ﲏ' - 1.00000000
# . 1
# Best fitness at generation 493: '視' - 1.00000000
# . 1
# Best fitness at generation 494: 'ﰸ' - 1.00000000
# . 1
# Best fitness at generation 495: 'ﱘ' - 1.00000000
# . 1
# Best fitness at generation 496: 'ｦ' - 1.00000000
# . 1
# Best fitness at generation 497: 'ｙ' - 1.00000000
# . 1
# Best fitness at generation 498: 'כֿ' - 1.00000000
# . 1
# Best fitness at generation 499: 'ﯿ' - 1.00000000
# . 1
# Best fitness at generation 500: '︎' - 1.00000000
# . 1
# Best fitness at generation 501: '﹚' - 1.00000000
# . 1
# Best fitness at generation 502: 'ı' - 1.00000000
# . 1
# Best fitness at generation 503: 'B' - 1.00000000
# . 1
# Best fitness at generation 504: 'ﰴ' - 1.00000000
# . 1
# Best fitness at generation 505: 'ġ' - 1.00000000
# . 1
# Best fitness at generation 506: 'ﰈ' - 1.00000000
# . 1
# Best fitness at generation 507: 'о' - 1.00000000
# . 1
# Best fitness at generation 508: 't' - 1.00000000
# . 1
# Best fitness at generation 509: 'ﴊ' - 1.00000000
# . 1
# Best fitness at generation 510: '\x7f' - 1.00000000
# . 1
# Best fitness at generation 511: 'ﺤ' - 1.00000000
# . 1
# Best fitness at generation 512: 'ϖ' - 1.00000000
# . 1
# Best fitness at generation 513: 'ﾣ' - 1.00000000
# . 1
# Best fitness at generation 514: '︸' - 1.00000000
# . 1
# Best fitness at generation 515: '︹' - 1.00000000
# . 1
# Best fitness at generation 516: 'Ƌ' - 1.00000000
# . 1
# Best fitness at generation 517: '﷼' - 1.00000000
# . 1
# Best fitness at generation 518: 'P' - 1.00000000
# . 1
# Best fitness at generation 519: '﹍' - 1.00000000
# . 1
# Best fitness at generation 520: '¢' - 1.00000000
# . 1
# Best fitness at generation 521: '視' - 1.00000000
# . 1
# Best fitness at generation 522: '\uf83a' - 1.00000000
# . 1
# Best fitness at generation 523: 'ﰙ' - 1.00000000
# . 1
# Best fitness at generation 524: 'ﾷ' - 1.00000000
# . 1
# Best fitness at generation 525: 'Ȫ' - 1.00000000
# . 1
# Best fitness at generation 526: '\ufddb' - 1.00000000
# . 1
# Best fitness at generation 527: '&' - 1.00000000
# . 1
# Best fitness at generation 528: 'k' - 1.00000000
# . 1
# Best fitness at generation 529: '°' - 1.00000000
# . 1
# Best fitness at generation 530: '￬' - 1.00000000
# . 1
# Best fitness at generation 531: 'ﺞ' - 1.00000000
# . 1
# Best fitness at generation 532: '￭' - 1.00000000
# . 1
# Best fitness at generation 533: 'ﾤ' - 1.00000000
# . 1
# Best fitness at generation 534: 'ﻇ' - 1.00000000
# . 1
# Best fitness at generation 535: 'ﹷ' - 1.00000000
# . 1
# Best fitness at generation 536: '，' - 1.00000000
# . 1
# Best fitness at generation 537: '¢' - 1.00000000
# . 1
# Best fitness at generation 538: 'ﺰ' - 1.00000000
# . 1
# Best fitness at generation 539: 'ß' - 1.00000000
# . 1
# Best fitness at generation 540: '\x93' - 1.00000000
# . 1
# Best fitness at generation 541: 'ﯯ' - 1.00000000
# . 1
# Best fitness at generation 542: 'ﻞ' - 1.00000000
# . 1
# Best fitness at generation 543: 'ﻌ' - 1.00000000
# . 1
# Best fitness at generation 544: 'Ｃ' - 1.00000000
# . 1
# Best fitness at generation 545: 'ﱣ' - 1.00000000
# . 1
# Best fitness at generation 546: 'ﾧ' - 1.00000000
# . 1
# Best fitness at generation 547: '︕' - 1.00000000
# . 1
# Best fitness at generation 548: '︂' - 1.00000000
# . 1
# Best fitness at generation 549: '\x9d' - 1.00000000
# . 1
# Best fitness at generation 550: 'ﱡ' - 1.00000000
# . 1
# Best fitness at generation 551: 'ƒ' - 1.00000000
# . 1
# Best fitness at generation 552: 'ﻢ' - 1.00000000
# . 1
# Best fitness at generation 553: '\uf8b7' - 1.00000000
# . 1
# Best fitness at generation 554: 'Ŷ' - 1.00000000
# . 1
# Best fitness at generation 555: '\ufff9' - 1.00000000
# . 1
# Best fitness at generation 556: 'ﾢ' - 1.00000000
# . 1
# Best fitness at generation 557: 'ﻅ' - 1.00000000
# . 1
# Best fitness at generation 558: 'ｚ' - 1.00000000
# . 1
# Best fitness at generation 559: '\x9c' - 1.00000000
# . 1
# Best fitness at generation 560: 'זּ' - 1.00000000
# . 1
# Best fitness at generation 561: '\ufafd' - 1.00000000
# . 1
# Best fitness at generation 562: '劣' - 1.00000000
# . 1
# Best fitness at generation 563: '說' - 1.00000000
# . 1
# Best fitness at generation 564: '７' - 1.00000000
# . 1
# Best fitness at generation 565: '\t' - 1.00000000
# . 1
# Best fitness at generation 566: 'µ' - 1.00000000
# . 1
# Best fitness at generation 567: 'בֿ' - 1.00000000
# . 1
# Best fitness at generation 568: '\ufe67' - 1.00000000
# . 1
# Best fitness at generation 569: '\ufaee' - 1.00000000
# . 1
# Best fitness at generation 570: 'ﴒ' - 1.00000000
# . 1
# Best fitness at generation 571: '穀' - 1.00000000
# . 1
# Best fitness at generation 572: 'ﭓ' - 1.00000000
# . 1
# Best fitness at generation 573: '泌' - 1.00000000
# . 1
# Best fitness at generation 574: 'ﯬ' - 1.00000000
# . 1
# Best fitness at generation 575: 'ﲊ' - 1.00000000
# . 1
# Best fitness at generation 576: 'ﻲ' - 1.00000000
# . 1
# Best fitness at generation 577: '/' - 1.00000000
# . 1
# Best fitness at generation 578: 'ﰭ' - 1.00000000
# . 1
# Best fitness at generation 579: '\uf7ea' - 1.00000000
# . 1
# Best fitness at generation 580: '塀' - 1.00000000
# . 1
# Best fitness at generation 581: 'ﮠ' - 1.00000000
# . 1
# Best fitness at generation 582: '\uf7a9' - 1.00000000
# . 1
# Best fitness at generation 583: '諾' - 1.00000000
# . 1
# Best fitness at generation 584: '𢡊' - 1.00000000
# . 1
# Best fitness at generation 585: '\uf818' - 1.00000000
# . 1
# Best fitness at generation 586: '缾' - 1.00000000
# . 1
# Best fitness at generation 587: '禮' - 1.00000000
# . 1
# Best fitness at generation 588: '\uf84a' - 1.00000000
# . 1
# Best fitness at generation 589: '倫' - 1.00000000
# . 1
# Best fitness at generation 590: '樂' - 1.00000000
# . 1
# Best fitness at generation 591: '\uf740' - 1.00000000
# . 1
# Best fitness at generation 592: '杻' - 1.00000000
# . 1
# Best fitness at generation 593: '\ufae0' - 1.00000000
# . 1
# Best fitness at generation 594: 'ﭮ' - 1.00000000
# . 1
# Best fitness at generation 595: '層' - 1.00000000
# . 1
# Best fitness at generation 596: 'ﭢ' - 1.00000000
# . 1
# Best fitness at generation 597: '\ufaea' - 1.00000000
# . 1
# Best fitness at generation 598: 'ﭳ' - 1.00000000
# . 1
# Best fitness at generation 599: '喇' - 1.00000000
# . 1
# Best fitness at generation 600: '瘝' - 1.00000000
# . 1
# Best fitness at generation 601: '\uf6a2' - 1.00000000
# . 1
# Best fitness at generation 602: '\uf4f8' - 1.00000000
# . 1
# Best fitness at generation 603: 'ﲄ' - 1.00000000
# . 1
# Best fitness at generation 604: 'ﭦ' - 1.00000000
# . 1
# Best fitness at generation 605: '\uf884' - 1.00000000
# . 1
# Best fitness at generation 606: '\uf54e' - 1.00000000
# . 1
# Best fitness at generation 607: '\uf771' - 1.00000000
# . 1
# Best fitness at generation 608: '\uf72d' - 1.00000000
# . 1
# Best fitness at generation 609: 'ﱥ' - 1.00000000
# . 1
# Best fitness at generation 610: '咽' - 1.00000000
# . 1
# Best fitness at generation 611: '\uf616' - 1.00000000
# . 1
# Best fitness at generation 612: '︗' - 1.00000000
# . 1
# Best fitness at generation 613: '漏' - 1.00000000
# . 1
# Best fitness at generation 614: '\uf6d2' - 1.00000000
# . 1
# Best fitness at generation 615: '\ufae2' - 1.00000000
# . 1
# Best fitness at generation 616: '歹' - 1.00000000
# . 1
# Best fitness at generation 617: '識' - 1.00000000
# . 1
# Best fitness at generation 618: '不' - 1.00000000
# . 1
# Best fitness at generation 619: 'ﶖ' - 1.00000000
# . 1
# Best fitness at generation 620: '龜' - 1.00000000
# . 1
# Best fitness at generation 621: 'ךּ' - 1.00000000
# . 1
# Best fitness at generation 622: '\ufb37' - 1.00000000
# . 1
# Best fitness at generation 623: 'ﮉ' - 1.00000000
# . 1
# Best fitness at generation 624: '\uf324' - 1.00000000
# . 1
# Best fitness at generation 625: '\ufb19' - 1.00000000
# . 1
# Best fitness at generation 626: '遼' - 1.00000000
# . 1
# Best fitness at generation 627: '\uf86c' - 1.00000000
# . 1
# Best fitness at generation 628: '\ufae2' - 1.00000000
# . 1
# Best fitness at generation 629: 'ﮐ' - 1.00000000
# . 1
# Best fitness at generation 630: 'זּ' - 1.00000000
# . 1
# Best fitness at generation 631: '\uf82f' - 1.00000000
# . 1
# Best fitness at generation 632: 'ﱃ' - 1.00000000
# . 1
# Best fitness at generation 633: '祐' - 1.00000000
# . 1
# Best fitness at generation 634: '﯀' - 1.00000000
# . 1
# Best fitness at generation 635: '紐' - 1.00000000
# . 1
# Best fitness at generation 636: 'ﱨ' - 1.00000000
# . 1
# Best fitness at generation 637: 'ﴁ' - 1.00000000
# . 1
# Best fitness at generation 638: '懲' - 1.00000000
# . 1
# Best fitness at generation 639: '磊' - 1.00000000
# . 1
# Best fitness at generation 640: '繁' - 1.00000000
# . 1
# Best fitness at generation 641: '\ufd4a' - 1.00000000
# . 1
# Best fitness at generation 642: '樂' - 1.00000000
# . 1
# Best fitness at generation 643: '渚' - 1.00000000
# . 1
# Best fitness at generation 644: '屮' - 1.00000000
# . 1
# Best fitness at generation 645: '\uf64a' - 1.00000000
# . 1
# Best fitness at generation 646: '\uf499' - 1.00000000
# . 1
# Best fitness at generation 647: 'ﲮ' - 1.00000000
# . 1
# Best fitness at generation 648: '略' - 1.00000000
# . 1
# Best fitness at generation 649: 'Ｘ' - 1.00000000
# . 1
# Best fitness at generation 650: '禮' - 1.00000000
# . 1
# Best fitness at generation 651: '諭' - 1.00000000
# . 1
# Best fitness at generation 652: 'ﾵ' - 1.00000000
# . 1
# Best fitness at generation 653: '\uf535' - 1.00000000
# . 1
# Best fitness at generation 654: '\uf747' - 1.00000000
# . 1
# Best fitness at generation 655: '\ufbc4' - 1.00000000
# . 1
# Best fitness at generation 656: '祐' - 1.00000000
# . 1
# Best fitness at generation 657: 'ﻚ' - 1.00000000
# . 1
# Best fitness at generation 658: 'ﲜ' - 1.00000000
# . 1
# Best fitness at generation 659: '拉' - 1.00000000
# . 1
# Best fitness at generation 660: '\uf8ba' - 1.00000000
# . 1
# Best fitness at generation 661: 'ﰡ' - 1.00000000
# . 1
# Best fitness at generation 662: 'ﯷ' - 1.00000000
# . 1
# Best fitness at generation 663: '﹖' - 1.00000000
# . 1
# Best fitness at generation 664: '陸' - 1.00000000
# . 1
# Best fitness at generation 665: 'ﺯ' - 1.00000000
# . 1
# Best fitness at generation 666: '\ufde7' - 1.00000000
# . 1
# Best fitness at generation 667: '嶺' - 1.00000000
# . 1
# Best fitness at generation 668: 'ﻝ' - 1.00000000
# . 1
# Best fitness at generation 669: 'ﰃ' - 1.00000000
# . 1
# Best fitness at generation 670: 'Ņ' - 1.00000000
# . 1
# Best fitness at generation 671: '\uf5c2' - 1.00000000
# . 1
# Best fitness at generation 672: '櫓' - 1.00000000
# . 1
# Best fitness at generation 673: 'ɭ' - 1.00000000
# . 1
# Best fitness at generation 674: 'ȴ' - 1.00000000
# . 1
# Best fitness at generation 675: 'ﻮ' - 1.00000000
# . 1
# Best fitness at generation 676: 'ﻣ' - 1.00000000
# . 1
# Best fitness at generation 677: 'ﻝ' - 1.00000000
# . 1
# Best fitness at generation 678: '\ufd4c' - 1.00000000
# . 1
# Best fitness at generation 679: '\uf3ad' - 1.00000000
# . 1
# Best fitness at generation 680: '嶺' - 1.00000000
# . 1
# Best fitness at generation 681: '猪' - 1.00000000
# . 1
# Best fitness at generation 682: 'ﻳ' - 1.00000000
# . 1
# Best fitness at generation 683: 'ﾇ' - 1.00000000
# . 1
# Best fitness at generation 684: '卑' - 1.00000000
# . 1
# Best fitness at generation 685: '簾' - 1.00000000
# . 1
# Best fitness at generation 686: '\uf6bf' - 1.00000000
# . 1
# Best fitness at generation 687: 'ﬆ' - 1.00000000
# . 1
# Best fitness at generation 688: 'C' - 1.00000000
# . 1
# Best fitness at generation 689: '\u0382' - 1.00000000
# . 1
# Best fitness at generation 690: '\uf85e' - 1.00000000
# . 1
# Best fitness at generation 691: '漢' - 1.00000000
# . 1
# Best fitness at generation 692: 'ʡ' - 1.00000000
# . 1
# Best fitness at generation 693: 'ˠ' - 1.00000000
# . 1
# Best fitness at generation 694: '\uf6d5' - 1.00000000
# . 1
# Best fitness at generation 695: 'ﱚ' - 1.00000000
# . 1
# Best fitness at generation 696: '瘝' - 1.00000000
# . 1
# Best fitness at generation 697: '爫' - 1.00000000
# . 1
# Best fitness at generation 698: '都' - 1.00000000
# . 1
# Best fitness at generation 699: '̲' - 1.00000000
# . 1
# Best fitness at generation 700: 'ɀ' - 1.00000000
# . 1
# Best fitness at generation 701: 'ﶋ' - 1.00000000
# . 1
# Best fitness at generation 702: '瑱' - 1.00000000
# . 1
# Best fitness at generation 703: '﯁' - 1.00000000
# . 1
# Best fitness at generation 704: '\uf8a1' - 1.00000000
# . 1
# Best fitness at generation 705: '\x95' - 1.00000000
# . 1
# Best fitness at generation 706: '\x9d' - 1.00000000
# . 1
# Best fitness at generation 707: '犯' - 1.00000000
# . 1
# Best fitness at generation 708: '͵' - 1.00000000
# . 1
# Best fitness at generation 709: 'Ġ' - 1.00000000
# . 1
# Best fitness at generation 710: '﹖' - 1.00000000
# . 1
# Best fitness at generation 711: 'M' - 1.00000000
# . 1
# Best fitness at generation 712: '裏' - 1.00000000
# . 1
# Best fitness at generation 713: 'ƥ' - 1.00000000
# . 1
# Best fitness at generation 714: 'ŝ' - 1.00000000
# . 1
# Best fitness at generation 715: '\uf880' - 1.00000000
# . 1
# Best fitness at generation 716: 'ǩ' - 1.00000000
# . 1
# Best fitness at generation 717: 'Ɣ' - 1.00000000
# . 1
# Best fitness at generation 718: 'ʧ' - 1.00000000
# . 1
# Best fitness at generation 719: '諭' - 1.00000000
# . 1
# Best fitness at generation 720: 'ʞ' - 1.00000000
# . 1
# Best fitness at generation 721: 'ﮔ' - 1.00000000
# . 1
# Best fitness at generation 722: '˾' - 1.00000000
# . 1
# Best fitness at generation 723: 'ͱ' - 1.00000000
# . 1
# Best fitness at generation 724: '\uf8b6' - 1.00000000
# . 1
# Best fitness at generation 725: 'ͅ' - 1.00000000
# . 1
# Best fitness at generation 726: '益' - 1.00000000
# . 1
# Best fitness at generation 727: 'ƶ' - 1.00000000
# . 1
# Best fitness at generation 728: '\uf85c' - 1.00000000
# . 1
# Best fitness at generation 729: '卵' - 1.00000000
# . 1
# Best fitness at generation 730: 'š' - 1.00000000
# . 1
# Best fitness at generation 731: '丹' - 1.00000000
# . 1
# Best fitness at generation 732: 'ʈ' - 1.00000000
# . 1
# Best fitness at generation 733: '̴' - 1.00000000
# . 1
# Best fitness at generation 734: 'Ɂ' - 1.00000000
# . 1
# Best fitness at generation 735: '惘' - 1.00000000
# . 1
# Best fitness at generation 736: '\uf696' - 1.00000000
# . 1
# Best fitness at generation 737: 'ԃ' - 1.00000000
# . 1
# Best fitness at generation 738: '稜' - 1.00000000
# . 1
# Best fitness at generation 739: '量' - 1.00000000
# . 1
# Best fitness at generation 740: '̼' - 1.00000000
# . 1
# Best fitness at generation 741: '泥' - 1.00000000
# . 1
# Best fitness at generation 742: '都' - 1.00000000
# . 1
# Best fitness at generation 743: '\ufdef' - 1.00000000
# . 1
# Best fitness at generation 744: 'ﺳ' - 1.00000000
# . 1
# Best fitness at generation 745: 'ﳱ' - 1.00000000
# . 1
# Best fitness at generation 746: 'ﲽ' - 1.00000000
# . 1
# Best fitness at generation 747: '燎' - 1.00000000
# . 1
# Best fitness at generation 748: 'Q' - 1.00000000
# . 1
# Best fitness at generation 749: '﨨' - 1.00000000
# . 1
# Best fitness at generation 750: 'Ǵ' - 1.00000000
# . 1
# Best fitness at generation 751: '數' - 1.00000000
# . 1
# Best fitness at generation 752: 'ﯙ' - 1.00000000
# . 1
# Best fitness at generation 753: 't' - 1.00000000
# . 1
# Best fitness at generation 754: '鶴' - 1.00000000
# . 1
# Best fitness at generation 755: 'ﱀ' - 1.00000000
# . 1
# Best fitness at generation 756: 'N' - 1.00000000
# . 1
# Best fitness at generation 757: 'Ɔ' - 1.00000000
# . 1
# Best fitness at generation 758: '器' - 1.00000000
# . 1
# Best fitness at generation 759: '\ufae7' - 1.00000000
# . 1
# Best fitness at generation 760: 'î' - 1.00000000
# . 1
# Best fitness at generation 761: '逸' - 1.00000000
# . 1
# Best fitness at generation 762: 'ɋ' - 1.00000000
# . 1
# Best fitness at generation 763: 'ﴴ' - 1.00000000
# . 1
# Best fitness at generation 764: '\uf729' - 1.00000000
# . 1
# Best fitness at generation 765: '\uf7e9' - 1.00000000
# . 1
# Best fitness at generation 766: '«' - 1.00000000
# . 1
# Best fitness at generation 767: 'Ƿ' - 1.00000000
# . 1
# Best fitness at generation 768: '\uf7e5' - 1.00000000
# . 1
# Best fitness at generation 769: 'ɦ' - 1.00000000
# . 1
# Best fitness at generation 770: '阮' - 1.00000000
# . 1
# Best fitness at generation 771: '\uf896' - 1.00000000
# . 1
# Best fitness at generation 772: '兩' - 1.00000000
# . 1
# Best fitness at generation 773: 'ﻶ' - 1.00000000
# . 1
# Best fitness at generation 774: '愈' - 1.00000000
# . 1
# Best fitness at generation 775: '＠' - 1.00000000
# . 1
# Best fitness at generation 776: '\ufafd' - 1.00000000
# . 1
# Best fitness at generation 777: 'ɤ' - 1.00000000
# . 1
# Best fitness at generation 778: 'Ŗ' - 1.00000000
# . 1
# Best fitness at generation 779: '羽' - 1.00000000
# . 1
# Best fitness at generation 780: '\uf7de' - 1.00000000
# . 1
# Best fitness at generation 781: '\x1b' - 1.00000000
# . 1
# Best fitness at generation 782: '晴' - 1.00000000
# . 1
# Best fitness at generation 783: 'ﹿ' - 1.00000000
# . 1
# Best fitness at generation 784: '瞧' - 1.00000000
# . 1
# Best fitness at generation 785: '\uf80b' - 1.00000000
# . 1
# Best fitness at generation 786: '\uf840' - 1.00000000
# . 1
# Best fitness at generation 787: '裏' - 1.00000000
# . 1
# Best fitness at generation 788: '\x92' - 1.00000000
# . 1
# Best fitness at generation 789: '\x06' - 1.00000000
# . 1
# Best fitness at generation 790: 'Ń' - 1.00000000
# . 1
# Best fitness at generation 791: '\uf855' - 1.00000000
# . 1
# Best fitness at generation 792: '\ufb3f' - 1.00000000
# . 1
# Best fitness at generation 793: 'ƍ' - 1.00000000
# . 1
# Best fitness at generation 794: 'ﳖ' - 1.00000000
# . 1
# Best fitness at generation 795: '\uf83b' - 1.00000000
# . 1
# Best fitness at generation 796: '\uf857' - 1.00000000
# . 1
# Best fitness at generation 797: '\uf72b' - 1.00000000
# . 1
# Best fitness at generation 798: 'ﳴ' - 1.00000000
# . 1
# Best fitness at generation 799: 'ȑ' - 1.00000000
# . 1
# Best fitness at generation 800: '\uf860' - 1.00000000
# . 1
# Best fitness at generation 801: '\uf855' - 1.00000000
# . 1
# Best fitness at generation 802: 'ﮱ' - 1.00000000
# . 1
# Best fitness at generation 803: '勤' - 1.00000000
# . 1
# Best fitness at generation 804: 'ﯽ' - 1.00000000
# . 1
# Best fitness at generation 805: 'ʖ' - 1.00000000
# . 1
# Best fitness at generation 806: '\ufb1a' - 1.00000000
# . 1
# Best fitness at generation 807: 'ﴡ' - 1.00000000
# . 1
# Best fitness at generation 808: 'ﮦ' - 1.00000000
# . 1
# Best fitness at generation 809: 'Ă' - 1.00000000
# . 1
# Best fitness at generation 810: '\uffe7' - 1.00000000
# . 1
# Best fitness at generation 811: '\uf734' - 1.00000000
# . 1
# Best fitness at generation 812: '遲' - 1.00000000
# . 1
# Best fitness at generation 813: 'ｧ' - 1.00000000
# . 1
# Best fitness at generation 814: 'ｋ' - 1.00000000
# . 1
# Best fitness at generation 815: '\uf6bc' - 1.00000000
# . 1
# Best fitness at generation 816: 'ƹ' - 1.00000000
# . 1
# Best fitness at generation 817: 'Ě' - 1.00000000
# . 1
# Best fitness at generation 818: 'Ӄ' - 1.00000000
# . 1
# Best fitness at generation 819: '\uf7fb' - 1.00000000
# . 1
# Best fitness at generation 820: 'Ҡ' - 1.00000000
# . 1
# Best fitness at generation 821: 'Ũ' - 1.00000000
# . 1
# Best fitness at generation 822: '\uf84c' - 1.00000000
# . 1
# Best fitness at generation 823: 'ﲚ' - 1.00000000
# . 1
# Best fitness at generation 824: 'Ǎ' - 1.00000000
# . 1
# Best fitness at generation 825: 'ｈ' - 1.00000000
# . 1
# Best fitness at generation 826: '\uf156' - 1.00000000
# . 1
# Best fitness at generation 827: 'ʳ' - 1.00000000
# . 1
# Best fitness at generation 828: 'ￎ' - 1.00000000
# . 1
# Best fitness at generation 829: 'ﲉ' - 1.00000000
# . 1
# Best fitness at generation 830: 'å' - 1.00000000
# . 1
# Best fitness at generation 831: '×' - 1.00000000
# . 1
# Best fitness at generation 832: '\uf282' - 1.00000000
# . 1
# Best fitness at generation 833: 'ﲀ' - 1.00000000
# . 1
# Best fitness at generation 834: '\uf416' - 1.00000000
# . 1
# Best fitness at generation 835: 'Ю' - 1.00000000
# . 1
# Best fitness at generation 836: 'ﺦ' - 1.00000000
# . 1
# Best fitness at generation 837: '\uf438' - 1.00000000
# . 1
# Best fitness at generation 838: 'ﴍ' - 1.00000000
# . 1
# Best fitness at generation 839: 'Ա' - 1.00000000
# . 1
# Best fitness at generation 840: 'Ĳ' - 1.00000000
# . 1
# Best fitness at generation 841: 'ﲸ' - 1.00000000
# . 1
# Best fitness at generation 842: '﹝' - 1.00000000
# . 1
# Best fitness at generation 843: 'Ǜ' - 1.00000000
# . 1
# Best fitness at generation 844: 'ﲛ' - 1.00000000
# . 1
# Best fitness at generation 845: 'ﲢ' - 1.00000000
# . 1
# Best fitness at generation 846: '\uf589' - 1.00000000
# . 1
# Best fitness at generation 847: 'Ϊ' - 1.00000000
# . 1
# Best fitness at generation 848: 'ﭘ' - 1.00000000
# . 1
# Best fitness at generation 849: 'ﷇ' - 1.00000000
# . 1
# Best fitness at generation 850: 'ﱷ' - 1.00000000
# . 1
# Best fitness at generation 851: '＃' - 1.00000000
# . 1
# Best fitness at generation 852: 'ﴥ' - 1.00000000
# . 1
# Best fitness at generation 853: '\ufdd3' - 1.00000000
# . 1
# Best fitness at generation 854: 'ﾛ' - 1.00000000
# . 1
# Best fitness at generation 855: 'ﯡ' - 1.00000000
# . 1
# Best fitness at generation 856: 'ﾔ' - 1.00000000
# . 1
# Best fitness at generation 857: 'Ѹ' - 1.00000000
# . 1
# Best fitness at generation 858: 'ͭ' - 1.00000000
# . 1
# Best fitness at generation 859: '︎' - 1.00000000
# . 1
# Best fitness at generation 860: 'ﺀ' - 1.00000000
# . 1
# Best fitness at generation 861: 'ﶈ' - 1.00000000
# . 1
# Best fitness at generation 862: 'ﲍ' - 1.00000000
# . 1
# Best fitness at generation 863: '\n' - 1.00000000
# . 1
# Best fitness at generation 864: 'ﵼ' - 1.00000000
# . 1
# Best fitness at generation 865: '\ufd42' - 1.00000000
# . 1
# Best fitness at generation 866: 'ￃ' - 1.00000000
# . 1
# Best fitness at generation 867: '︦' - 1.00000000
# . 1
# Best fitness at generation 868: 'ｴ' - 1.00000000
# . 1
# Best fitness at generation 869: 'ﹳ' - 1.00000000
# . 1
# Best fitness at generation 870: 'ﺇ' - 1.00000000
# . 1
# Best fitness at generation 871: '\uec86' - 1.00000000
# . 1
# Best fitness at generation 872: '˭' - 1.00000000
# . 1
# Best fitness at generation 873: 'ￌ' - 1.00000000
# . 1
# Best fitness at generation 874: '呂' - 1.00000000
# . 1
# Best fitness at generation 875: 'ﻄ' - 1.00000000
# . 1
# Best fitness at generation 876: '\uf8a0' - 1.00000000
# . 1
# Best fitness at generation 877: 'ö' - 1.00000000
# . 1
# Best fitness at generation 878: '\ueaf9' - 1.00000000
# . 1
# Best fitness at generation 879: 'ｑ' - 1.00000000
# . 1
# Best fitness at generation 880: 'ﵰ' - 1.00000000
# . 1
# Best fitness at generation 881: '\x12' - 1.00000000
# . 1
# Best fitness at generation 882: 'ﱙ' - 1.00000000
# . 1
# Best fitness at generation 883: '\ued83' - 1.00000000
# . 1
# Best fitness at generation 884: 'Ｄ' - 1.00000000
# . 1
# Best fitness at generation 885: '茶' - 1.00000000
# . 1
# Best fitness at generation 886: '諒' - 1.00000000
# . 1
# Best fitness at generation 887: '煉' - 1.00000000
# . 1
# Best fitness at generation 888: '\uef8e' - 1.00000000
# . 1
# Best fitness at generation 889: '\ufae1' - 1.00000000
# . 1
# Best fitness at generation 890: 'ﻍ' - 1.00000000
# . 1
# Best fitness at generation 891: '︴' - 1.00000000
# . 1
# Best fitness at generation 892: '\x93' - 1.00000000
# . 1
# Best fitness at generation 893: 'ﱎ' - 1.00000000
# . 1
# Best fitness at generation 894: 'Ｕ' - 1.00000000
# . 1
# Best fitness at generation 895: 'À' - 1.00000000
# . 1
# Best fitness at generation 896: 'ć' - 1.00000000
# . 1
# Best fitness at generation 897: 'ﰪ' - 1.00000000
# . 1
# Best fitness at generation 898: '\uee27' - 1.00000000
# . 1
# Best fitness at generation 899: '«' - 1.00000000
# . 1
# Best fitness at generation 900: 'ﰩ' - 1.00000000
# . 1
# Best fitness at generation 901: 'Ƅ' - 1.00000000
# . 1
# Best fitness at generation 902: 'Ñ' - 1.00000000
# . 1
# Best fitness at generation 903: '/' - 1.00000000
# . 1
# Best fitness at generation 904: 'Ý' - 1.00000000
# . 1
# Best fitness at generation 905: '\uffe7' - 1.00000000
# . 1
# Best fitness at generation 906: '~' - 1.00000000
# . 1
# Best fitness at generation 907: 'Ň' - 1.00000000
# . 1
# Best fitness at generation 908: 'ƚ' - 1.00000000
# . 1
# Best fitness at generation 909: 'ø' - 1.00000000
# . 1
# Best fitness at generation 910: '\x9a' - 1.00000000
# . 1
# Best fitness at generation 911: '參' - 1.00000000
# . 1
# Best fitness at generation 912: '﨓' - 1.00000000
# . 1
# Best fitness at generation 913: 'ʫ' - 1.00000000
# . 1
# Best fitness at generation 914: 'ﾳ' - 1.00000000
# . 1
# Best fitness at generation 915: '\ued40' - 1.00000000
# . 1
# Best fitness at generation 916: '\uee74' - 1.00000000
# . 1
# Best fitness at generation 917: "'" - 1.00000000
# . 1
# Best fitness at generation 918: 'ｄ' - 1.00000000
# . 1
# Best fitness at generation 919: 'ж' - 1.00000000
# . 1
# Best fitness at generation 920: '\x80' - 1.00000000
# . 1
# Best fitness at generation 921: 'ﹸ' - 1.00000000
# . 1
# Best fitness at generation 922: '=' - 1.00000000
# . 1
# Best fitness at generation 923: 'ﹿ' - 1.00000000
# . 1
# Best fitness at generation 924: '^' - 1.00000000
# . 1
# Best fitness at generation 925: 'Ｏ' - 1.00000000
# . 1
# Best fitness at generation 926: 'ǥ' - 1.00000000
# . 1
# Best fitness at generation 927: '\uffef' - 1.00000000
# . 1
# Best fitness at generation 928: 'Э' - 1.00000000
# . 1
# Best fitness at generation 929: 'ｻ' - 1.00000000
# . 1
# Best fitness at generation 930: '\uef10' - 1.00000000
# . 1
# Best fitness at generation 931: 'ﾤ' - 1.00000000
# . 1
# Best fitness at generation 932: 'ȧ' - 1.00000000
# . 1
# Best fitness at generation 933: 'ͭ' - 1.00000000
# . 1
# Best fitness at generation 934: '\x05' - 1.00000000
# . 1
# Best fitness at generation 935: 'ﶼ' - 1.00000000
# . 1
# Best fitness at generation 936: 'ȓ' - 1.00000000
# . 1
# Best fitness at generation 937: 'Ǔ' - 1.00000000
# . 1
# Best fitness at generation 938: 'Ƿ' - 1.00000000
# . 1
# Best fitness at generation 939: 'h' - 1.00000000
# . 1
# Best fitness at generation 940: '×' - 1.00000000
# . 1
# Best fitness at generation 941: 'Ǭ' - 1.00000000
# . 1
# Best fitness at generation 942: 'ʀ' - 1.00000000
# . 1
# Best fitness at generation 943: 'Ʌ' - 1.00000000
# . 1
# Best fitness at generation 944: 'ʁ' - 1.00000000
# . 1
# Best fitness at generation 945: 'ù' - 1.00000000
# . 1
# Best fitness at generation 946: 'ȥ' - 1.00000000
# . 1
# Best fitness at generation 947: 'ɠ' - 1.00000000
# . 1
# Best fitness at generation 948: 'ɏ' - 1.00000000
# . 1
# Best fitness at generation 949: 'ř' - 1.00000000
# . 1
# Best fitness at generation 950: 'ـ' - 1.00000000
# . 1
# Best fitness at generation 951: 'ˍ' - 1.00000000
# . 1
# Best fitness at generation 952: 'Ŕ' - 1.00000000
# . 1
# Best fitness at generation 953: 'Ϊ' - 1.00000000
# . 1
# Best fitness at generation 954: '\ufff9' - 1.00000000
# . 1
# Best fitness at generation 955: 'ﺨ' - 1.00000000
# . 1
# Best fitness at generation 956: '˙' - 1.00000000
# . 1
# Best fitness at generation 957: '7' - 1.00000000
# . 1.0
# Best fitness at generation 958: 'в' - 1.00000000
# . 1
# Best fitness at generation 959: 'ͬ' - 1.00000000
# . 1
# Best fitness at generation 960: 'ʕ' - 1.00000000
# . 1
# Best fitness at generation 961: 'Ы' - 1.00000000
# . 1
# Best fitness at generation 962: '\u058c' - 1.00000000
# . 1
# Best fitness at generation 963: 'ˎ' - 1.00000000
# . 1
# Best fitness at generation 964: 'ɺ' - 1.00000000
# . 1
# Best fitness at generation 965: 'æ' - 1.00000000
# . 1
# Best fitness at generation 966: 'Ԋ' - 1.00000000
# . 1
# Best fitness at generation 967: '̛' - 1.00000000
# . 1
# Best fitness at generation 968: 'ﶰ' - 1.00000000
# . 1
# Best fitness at generation 969: '9' - 1.00000000
# . 1.0
# Best fitness at generation 970: '*' - 1.00000000
# . 1
# Best fitness at generation 971: 'Ӱ' - 1.00000000
# . 1
# Best fitness at generation 972: 'ﵸ' - 1.00000000
# . 1
# Best fitness at generation 973: 'ȓ' - 1.00000000
# . 1
# Best fitness at generation 974: '[' - 1.00000000
# . 1
# Best fitness at generation 975: 'Ǟ' - 1.00000000
# . 1
# Best fitness at generation 976: '˅' - 1.00000000
# . 1
# Best fitness at generation 977: 'ƭ' - 1.00000000
# . 1
# Best fitness at generation 978: 'Ɓ' - 1.00000000
# . 1
# Best fitness at generation 979: 'ה' - 1.00000000
# . 1
# Best fitness at generation 980: 'š' - 1.00000000
# . 1
# Best fitness at generation 981: 'Ǉ' - 1.00000000
# . 1
# Best fitness at generation 982: 'Ɨ' - 1.00000000
# . 1
# Best fitness at generation 983: 'ﾢ' - 1.00000000
# . 1
# Best fitness at generation 984: 'Ƭ' - 1.00000000
# . 1
# Best fitness at generation 985: 'ĕ' - 1.00000000
# . 1
# Best fitness at generation 986: 'ȇ' - 1.00000000
# . 1
# Best fitness at generation 987: 'ɪ' - 1.00000000
# . 1
# Best fitness at generation 988: '﷽' - 1.00000000
# . 1
# Best fitness at generation 989: '\x91' - 1.00000000
# . 1
# Best fitness at generation 990: '̏' - 1.00000000
# . 1
# Best fitness at generation 991: '8' - 1.00000000
# . 1.0
# Best fitness at generation 992: 'ļ' - 1.00000000
# . 1
# Best fitness at generation 993: 'ﾰ' - 1.00000000
# . 1
# Best fitness at generation 994: 'ﳜ' - 1.00000000
# . 1
# Best fitness at generation 995: 'ﾏ' - 1.00000000
# . 1
# Best fitness at generation 996: 'Ͽ' - 1.00000000
# . 1
# Best fitness at generation 997: '\x93' - 1.00000000
# . 1
# Best fitness at generation 998: 'Ѩ' - 1.00000000
# . 1
# Best fitness at generation 999: 'γ' - 1.00000000
# . 1
# Best fitness at generation 1000: '\ufdeb' - 1.00000000
# Best individual: '\ufdeb', fitness 1.0000000000
# ('\ufdeb', 1)

# %%
class ExprEvolver(Evolver):
    def get_fitness(self, s):
        with ExpectExprError(s, log=self.log) as e:
            calculator.main(e.s)
        match e.result:
            case ExprStatus.Complete:
                return 1.0/len(e.s)
            case ExprStatus.Unexpected:
                return len(e.s) - e.boundary
            case ExprStatus.Unterminated:
                return 1
        assert False, (s, e)

# %%
expr_evolver = ExprEvolver(log=False)

# %%
for i in range(10):
    v = expr_evolver.genetic_algorithm()
    print(repr(v))
# Out:
# ('ׅ', 1)
# ('37', 0.5)
# ('\ueeb0', 1)
# ('ﴲ', 1)
# ('F', 1)
# ('蓼', 1)
# ('115', 0.3333333333333333)
# ('\uf8d0', 1)
# ('45', 0.5)
# ('\u0603', 1)

# %% [markdown]
# ### JSON
# Generating JSON can be slow. (Only if we have enough time).

# %%
class JStatus(enum.Enum):
    Complete = 0
    Extra = 1
    Unterminated = -1
    Expecting = -2

# %%
import subjects.microjson as microjson

# %%
class ExpectJSONError:
    def __init__(self, s=None, log=False):
        self.msg = None
        self.boundary = None
        self.result = None
        self.s = s
        self.log = log

    def __enter__(self):
        return self

    def __exit__(self, exc_type, exc_value, tb):
        if exc_type is None:
            self.boundary = 0
            self.result = JStatus.Complete
            return
        json_error = exc_value
        msg = str(exc_value)
        if self.log:
            print(msg, file=sys.stderr)
        if msg.startswith('extra data after JSON at position'):
            self.result = JStatus.Extra
        elif msg.startswith('malformed JSON data at position'):
            self.result = JStatus.Expecting
        elif msg.startswith('missing colon after key at position'):
            self.result = JStatus.Expecting
        elif msg.startswith('expected null at position'):
            self.result = JStatus.Expecting
        elif msg.startswith('expected boolean at position'):
            self.result = JStatus.Expecting
        elif msg.startswith('truncated JSON data at position'):                                                       
            self.result = JStatus.Unterminated
        else:
            # Not all exceptions have been specifically caught in the interest of simplicity.
            # assert False, msg
            self.result = JStatus.Expecting
        self.boundary = exc_value.pos
        return True

# %%
error_data = [
    #expected null at position 0, "'n%m\ri<Q8P<t{STo~V&iH|_pJu}8_*fB\r'"
    'n%m\ri<Q8P<t{STo~V&iH|_pJu}8_*fB\r',
    # expected boolean at position 0, "'tWI6n )AB/'"
    'tWI6n )AB/',
    # missing colon after key at position 36, "'fn1+"AC8fwp{@cQ'"
    'fn1+"AC8fwp{@cQ'
]

# %%
for x in error_data:
    with ExpectJSONError(x) as e:
        microjson.main(e.s)
    print(e.boundary, e.result)
# Out:
# 0 JStatus.Expecting
# 0 JStatus.Expecting
# 0 JStatus.Expecting

# %%
with ExpectJSONError() as e:
     microjson.main('["abc"]de')
e.boundary, e.result
# Out:
# (7, <JStatus.Extra: 1>)

# %%
with ExpectJSONError() as e:
     microjson.main('["abc')
e.boundary, e.result
# Out:
# (4, <JStatus.Unterminated: -1>)

# %%
with ExpectJSONError() as e:
     microjson.main('[ab')
e.boundary, e.result
# Out:
# (1, <JStatus.Expecting: -2>)

# %%
with ExpectJSONError() as e:
     microjson.main('[1,2,3]')
e.boundary, e.result
# Out:
# (0, <JStatus.Complete: 0>)

# %%
class JSONEvolver(Evolver):
    def get_fitness(self, s):
        with ExpectJSONError(s, self.log) as e:
            microjson.main(e.s)
        match e.result:
            case JStatus.Complete:
                return 1.0/len(e.s)
            case JStatus.Extra:
                return len(s) - e.boundary
                # better to be incomplete than incorrect.
                return len(s) * 0.1
            case JStatus.Expecting:
                if len(s) == e.boundary:
                    return 1
                return len(s) - e.boundary
            case JStatus.Unterminated:
                return 1
        assert False, (s, e)

# %%
json_evolver = JSONEvolver(log=False)

# %% [markdown]
# **Can be really slow**

# %%
for i in range(10):
    v = json_evolver.genetic_algorithm()
    print(repr(v))
# Out:
# ('"Ðđ𢡄＂ｾǳ\x89Ôￓ\t\x8fﻪｦŴģȣĿŉȕy\x00Â["', 0.04)
# (' 6', 0.5)
# ('ᅀ', 1)
# ('--', 0.5)
# ('שּׁ', 1)
# ('899', 0.3333333333333333)
# ('ʺ', 1)
# ('292', 0.3333333333333333)
# ('}', 1)
# ('"ÞąＵ\x9cｩr±_ａￚ\x1dç"', 0.07142857142857142)

# %% [markdown]
# # Done

# %%
#%tb
# Out:
# No traceback available to show.
